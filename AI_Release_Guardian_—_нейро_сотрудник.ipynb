# %% [markdown]
# # ***AI Release Guardian — нейро-сотрудник для анализа веб-интерфейсов***

# %% [markdown]
# # Описание проекта
#
# В данной работе реализован нейро-сотрудник **AI Release Guardian**, предназначенный для анализа веб-интерфейсов и выявления потенциальных проблем при выпуске новых версий продукта.
#
# Основная задача системы — помочь QA-инженеру автоматически:
#
# - анализировать структуру интерфейса веб-страницы
# - декомпозировать интерфейс на тестируемые элементы
# - группировать элементы по типам и классам эквивалентности
# - генерировать тестовые сценарии для элементов интерфейса
# - выявлять потенциальные зоны риска
# - анализировать изменения интерфейса между запусками
#
# Система выступает как **интеллектуальный помощник тестировщика**, который автоматически анализирует интерфейс страницы и формирует рекомендации по тестированию.
#
# ---
#
# # Архитектурная идея
#
# В отличие от классических RAG-чатботов, система использует **комбинированный подход анализа интерфейса**.
#
# Источники информации:
#
# 1. **DOM-анализ веб-страницы**
# Система извлекает реальную структуру интерфейса страницы с помощью Selenium и BeautifulSoup.
#
# 2. **База знаний QA-практик**
# Используется RAG-архитектура для получения рекомендаций по тестированию.
#
# 3. **LLM-анализ интерфейса**
# LLM используется для reasoning-задач: анализа рисков, генерации тестов и интерпретации изменений.
#
# Такой подход снижает вероятность галлюцинаций LLM, поскольку модель опирается на реальные данные интерфейса и структурированные артефакты анализа.
#
# ---
#
# # Основные технологии
#
# В проекте используются следующие технологии:
#
# - Python
# - Selenium
# - BeautifulSoup
# - LlamaIndex
# - HuggingFace Embeddings
# - RAG (Retrieval Augmented Generation)
# - локальная русскоязычная LLM
# - VSEGPT API для расширенного анализа
#
# ---
#
# # Роль нейро-сотрудника
#
# AI Release Guardian выступает в роли:
#
# **Senior QA Analyst**
#
# Он:
#
# - анализирует интерфейс страницы
# - выявляет потенциальные зоны риска
# - предлагает тестовые сценарии
# - помогает тестировщику определить приоритетные проверки перед релизом

# %% [markdown]
# # Архитектура системы AI Release Guardian
#
# В системе используется архитектура, объединяющая анализ DOM-структуры веб-страницы и RAG-подход для получения экспертных знаний по тестированию интерфейсов.
#
# Архитектура построена по принципу:
#
# - Code extracts facts → LLM performs reasoning
#
# Это снижает вероятность галлюцинаций модели, поскольку LLM выполняет анализ на основе структурированных данных интерфейса.
#
# ---
#
# # Общая схема работы системы
#
#
#
#
# ```
# TARGET_URL
# ↓
# DOM анализ страницы (Selenium + BeautifulSoup)
# ↓
# Декомпозиция интерфейса → testable_objects
# ↓
# Группировка элементов по типам (representative elements)
# ↓
# Генерация тестов для типов элементов (LLM + rule-based)
# ↓
# Формирование summary страницы
# ↓
# Site-level UI checks
# ↓
# Visual consistency checks
# ↓
# AI-анализ рисков страницы
# ↓
# Сравнение запусков (UI diff)
# ↓
# AI-анализ изменений
# ↓
# Release risk analysis
# ↓
# Сохранение run-артефактов
# ```
#
#
#
#  ---
#
#
# # Основные компоненты системы
#
# ## 1. DOM-анализ
#
# Система получает HTML страницы и извлекает элементы интерфейса.
#
# Используются:
#
# - Selenium — для загрузки страницы
# - BeautifulSoup — для анализа DOM
#
# Извлекаются основные элементы интерфейса:
#
# - input
# - button
# - form
# - link
# - table
# - image
#
# ---
#
# ## 2. Декомпозиция интерфейса
#
# Интерфейс разбивается на **testable objects** — элементы, которые могут быть протестированы.
#
# Пример:
#
# ```
# input → поле ввода
# button → кнопка
# checkbox → переключатель
# ```
# ---
#
# После этого элементы **группируются по типам**, и для каждого типа выбирается **representative element**, который используется для генерации тестов класса эквивалентных элементов.
#
# ---
#
# ## 3. RAG-слой
#
# Для анализа используются знания из базы QA-практик.
#
# Система:
#
# 1. извлекает релевантные документы
# 2. передает их LLM
# 3. использует полученный контекст при генерации тестов и анализе интерфейса
#
# Это позволяет использовать проверенные рекомендации по тестированию.
#
# # Приемы улучшения RAG в проекте
#
# В проекте используются следующие приемы улучшения RAG:
#
# 1. Grounded retrieval на основе реальных UI-элементов
#    Запрос к базе знаний формируется на основе DOM-атрибутов и testable objects.
#
# 2. Структурирование входных данных
#    Перед использованием LLM интерфейс переводится в testable objects, page_summary и diff_report, что уменьшает шум и снижает вероятность галлюцинаций.
#
# 3. Использование representative elements
#    Элементы группируются по типам и рассматриваются как классы эквивалентности, что уменьшает дублирование и повышает устойчивость генерации.
#
# 4. Многоуровневый анализ
#    Система использует element-level, page-level и release-level анализ вместо одного общего ответа.
#
# 5. Run-based архитектура и diff analysis
#    Контекст анализа расширяется за счёт истории запусков и сравнения версий интерфейса.
#
# 6. Гибридное использование LLM
#    Для демонстрации используется локальная русскоязычная модель, а для более сложного reasoning — внешний LLM API.
#
# ---
#
# ## 4. AI-анализ
#
# LLM используется для задач reasoning:
#
# - генерации тестовых сценариев
# - анализа UX-рисков
# - поиска потенциальных баг-зон
# - анализа изменений интерфейса между запусками
#
# В проекте используются два типа моделей:
#
# - локальная русскоязычная LLM (экспериментальный слой анализа)
# - VSEGPT API (основной слой reasoning)
#
# ---
#
# ## 5. Run-based архитектура
#
# Каждый запуск анализа сохраняется как **run**, что позволяет:
#
# - хранить историю анализа интерфейса
# - сравнивать версии страницы
# - выявлять изменения между релизами
# - анализировать потенциальные зоны регрессии

# %% [markdown]
# # Конфигурация проекта
#
# Для удобства воспроизводимости экспериментов основные параметры системы вынесены в отдельный конфигурационный блок.
#
# Это позволяет:
#
# - централизованно управлять параметрами системы
# - легко менять модели и настройки RAG
# - быстро переключаться между сайтами для анализа
# - упростить дальнейшее развитие проекта
#
# Использование отдельного конфигурационного блока делает систему более гибкой и облегчает повторное использование кода.
#
# ---
#
# ## В конфигурации задаются
#
# - TARGET_URL — адрес страницы для анализа
# - путь к базе знаний QA-практик
# - модель эмбеддингов
# - русскоязычная локальная LLM
# - параметры VSEGPT API
# - параметры retrieval (количество документов)
# - ограничения на размер контекста
# - параметры генерации LLM
#
# Такая структура позволяет легко адаптировать систему для анализа других веб-интерфейсов.

# %%
# ==========================================================
# CONFIG — конфигурация проекта AI Release Guardian
# ==========================================================
# Все ключевые параметры системы собраны в одном месте.
# Это упрощает изменение архитектуры и повышает
# воспроизводимость экспериментов.
# ==========================================================

CONFIG = {

    # Путь к базе знаний (папка в Google Drive)
    "KB_PATH": "/content/drive/MyDrive/AI_Release_Guardian_MVP",

    # Подпапки базы знаний
    "KB_THEORY_PATH": "/content/drive/MyDrive/AI_Release_Guardian_MVP/Theory",
    "KB_PORTFOLIO_PATH": "/content/drive/MyDrive/AI_Release_Guardian_MVP/Portfolio",
    "RUNS_ROOT": "/content/drive/MyDrive/AI_Release_Guardian_MVP/Sites",

    # Модель эмбеддингов для RAG
    "EMBEDDING_MODEL": "sentence-transformers/all-MiniLM-L6-v2",

    # Русскоязычная LLM (демонстрация локальной модели)
    "RU_LLM_MODEL": "Vikhrmodels/Vikhr-Qwen-2.5-1.5B-Instruct",

    # Количество документов, возвращаемых retriever
    "TOP_K_RETRIEVAL": 3,

    # Ограничение на количество документов для индекса
    # (нужно, чтобы Colab работал быстрее)
    "MAX_DOCUMENTS": 150,

    # Включение фильтра безопасности
    "ENABLE_SAFETY_FILTER": True,

    # По-умолчанию для запуска нейро-сотрудника будет использоваться следующий сайт
    "DEFAULT_TARGET_URL": "https://trainer.sedtest-tools.ru/checkpass/",

}

# Вывод конфигурации
print("Конфигурация проекта загружена:")
for key, value in CONFIG.items():
    print(f"{key}: {value}")
# Out:
# Конфигурация проекта загружена:
# KB_PATH: /content/drive/MyDrive/AI_Release_Guardian_MVP
# KB_THEORY_PATH: /content/drive/MyDrive/AI_Release_Guardian_MVP/Theory
# KB_PORTFOLIO_PATH: /content/drive/MyDrive/AI_Release_Guardian_MVP/Portfolio
# RUNS_ROOT: /content/drive/MyDrive/AI_Release_Guardian_MVP/Sites
# EMBEDDING_MODEL: sentence-transformers/all-MiniLM-L6-v2
# RU_LLM_MODEL: Vikhrmodels/Vikhr-Qwen-2.5-1.5B-Instruct
# TOP_K_RETRIEVAL: 3
# MAX_DOCUMENTS: 150
# ENABLE_SAFETY_FILTER: True
# DEFAULT_TARGET_URL: https://trainer.sedtest-tools.ru/checkpass/

# %% [markdown]
# # Установка зависимостей
#
# Для работы системы необходимо установить библиотеки, используемые в проекте.
#
# В проекте используются следующие группы библиотек.
#
# ---
#
# ## 1. Работа с документами
#
# - **docx2txt** — извлечение текста из Word-документов
# - **pypdf** — извлечение текста из PDF-файлов
# - **python-pptx** — извлечение текста из презентаций
#
# Эти библиотеки используются для загрузки базы знаний QA-практик.
#
# ---
#
# ## 2. RAG-архитектура
#
# - **llama-index** — построение RAG-индекса
# - **llama-index-embeddings-huggingface** — интеграция моделей эмбеддингов
#
# RAG используется для извлечения рекомендаций по тестированию из базы знаний.
#
# ---
#
# ## 3. Модели эмбеддингов
#
# - **sentence-transformers** — генерация векторных представлений текста
#
# Эмбеддинги используются для поиска релевантных документов в базе знаний.
#
# ---
#
# ## 4. Работа с DOM
#
# - **selenium** — автоматизация браузера и загрузка страницы
# - **beautifulsoup4** — парсинг HTML и анализ структуры DOM
#
# Эти инструменты используются для извлечения элементов интерфейса.
#
# ---
#
# ## 5. Локальная русскоязычная LLM
#
# - **transformers**
# - **accelerate**
# - **torch**
#
# Используются для загрузки и запуска локальной русскоязычной instruct-модели.
#
# ---
#
# ## 6. Работа с LLM API
#
# - **requests**
#
# Используется для обращения к VSEGPT API и выполнения расширенного анализа интерфейса.

# %%
# ==========================================================
# Установка зависимостей проекта
# ==========================================================
# Этот блок устанавливает все необходимые библиотеки.
# После установки Colab можно запускать на любой машине.
# ==========================================================

# !pip install -q docx2txt
# !pip install -q pypdf
# !pip install -q python-pptx
# !pip install -q jedi>=0.16

# Библиотеки для RAG
# !pip install -q llama-index
# !pip install -q llama-index-embeddings-huggingface

# Модель эмбеддингов
# !pip install -q sentence-transformers

# Работа с DOM
# !pip install -q selenium
# !pip install -q beautifulsoup4

# Локальная LLM
# !pip install -q transformers
# !pip install -q accelerate
# !pip install -q sentencepiece
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.2/332.2 kB 12.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.8/472.8 kB 17.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.3/175.3 kB 11.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 95.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 303.3/303.3 kB 24.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.0/107.0 kB 9.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.9/63.9 kB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 46.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.0/142.0 kB 9.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Подключение Google Drive
#
# Для хранения базы знаний и результатов анализа используется Google Drive.
#
# Использование Google Drive позволяет:
#
# - хранить базу знаний QA-практик
# - сохранять артефакты анализа интерфейсов
# - хранить историю запусков системы
# - сравнивать версии интерфейса между запусками
#
# Таким образом Google Drive выступает в роли **центра хранения данных проекта**.
#
# ---
#
# ## Структура данных проекта
#
# В Google Drive находятся:
#
# - документы базы знаний (Theory)
# - примеры проектов и материалов (Portfolio)
# - результаты анализа сайтов
# - артефакты запусков системы (runs)
#
# Пример структуры проекта:
#
#
# ```
# AI_Release_Guardian_MVP/
# │
# ├── Theory/
# │ ├── qa_testing_practices.pdf
# │ ├── ui_testing_methods.docx
# │
# ├── Portfolio/
# │ ├── example_projects.pdf
# │
# └── Sites/
# └── site_name/
# └── runs/
# ├── run_001/
# ├── run_002/
# └── run_003/
# ```
#
#
# ---
#
# ## Run-based архитектура
#
# Каждый запуск анализа сохраняется в отдельную папку **run**.
#
# Это позволяет:
#
# - хранить историю анализов интерфейса
# - сравнивать разные версии страницы
# - выполнять UI diff между запусками
# - анализировать потенциальные регрессии
#
# Каждый run содержит артефакты анализа, например:
#
# - testable_objects
# - generated_test_cases
# - site_risk_analysis
# - ui_diff_report
# - run_summary

# %%
# ==========================================================
# Подключение Google Drive
# ==========================================================
# Google Drive используется для хранения:
# - базы знаний
# - результатов анализа
# - истории запусков системы
# ==========================================================

from google.colab import drive

# Подключение Google Drive
drive.mount('/content/drive')

print("Google Drive успешно подключен")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Google Drive успешно подключен

# %%
# ==========================================================
# Проверка доступности базы знаний
# ==========================================================

import os

kb_path = CONFIG["KB_PATH"]

if os.path.exists(kb_path):
    print("Папка базы знаний найдена:", kb_path)
else:
    print("Папка базы знаний НЕ найдена:", kb_path)
# Out:
# Папка базы знаний найдена: /content/drive/MyDrive/AI_Release_Guardian_MVP

# %% [markdown]
# # Подготовка базы знаний
#
# Для работы нейро-сотрудника используется база знаний по QA-тестированию и анализу интерфейсов.
#
# База знаний позволяет системе опираться не только на общие вероятностные знания LLM, но и на релевантные материалы из QA-домена.
#
# В проекте используется подход **Retrieval Augmented Generation (RAG)**, при котором модель получает дополнительный контекст из документов базы знаний.
#
# ---
#
# ## Структура базы знаний
#
# В рамках данной работы база знаний состоит из двух основных частей.
#
# ### 1. Theory
#
# Теоретические материалы по:
#
# - тестированию интерфейсов
# - QA-подходам
# - принципам проектирования тестов
# - анализу UX/UI
#
# Эти документы используются для извлечения рекомендаций по тестированию интерфейсов.
#
# ---
#
# ### 2. Portfolio
#
# Практические материалы и примеры проектов.
#
# Такие документы могут использоваться как дополнительный контекст и примеры применения QA-практик.
#
# ---
#
# ## Почему база знаний важна
#
# Использование базы знаний позволяет:
#
# - уменьшить вероятность галлюцинаций модели
# - сделать ответы более предметными
# - привязать рекомендации к QA-домену
# - использовать RAG вместо «чистого» генеративного ответа
#
# Таким образом LLM выполняет reasoning на основе релевантного контекста.
#
# ---
#
# ## Форматы документов
#
# Система поддерживает несколько форматов документов:
#
# - PDF
# - DOCX
# - PPTX
# - TXT
#
# Это позволяет использовать разнообразные источники знаний при построении базы QA-практик.

# %%
# ==========================================================
# Подготовка базы знаний
# ==========================================================
# В этом блоке:
# 1. Проверяем наличие папок базы знаний
# 2. Собираем пути ко всем документам
# 3. Выводим краткую статистику по базе знаний
# ==========================================================

import os
from glob import glob

# Пути к основным разделам базы знаний
theory_path = CONFIG["KB_THEORY_PATH"]
portfolio_path = CONFIG["KB_PORTFOLIO_PATH"]

print("Проверка папок базы знаний...\n")

for path in [theory_path, portfolio_path]:
    if os.path.exists(path):
        print(f"[OK] Папка найдена: {path}")
    else:
        print(f"[WARN] Папка не найдена: {path}")

# Поддерживаемые форматы документов
supported_extensions = ["*.pdf", "*.docx", "*.pptx", "*.txt"]

def collect_files_from_folder(folder_path, extensions):
    """
    Собирает список файлов из папки по заданным расширениям.

    Аргументы:
        folder_path (str): путь к папке
        extensions (list): список шаблонов расширений (*.pdf и т.д.)

    Возвращает:
        list: список найденных файлов
    """
    files = []
    for ext in extensions:
        files.extend(glob(os.path.join(folder_path, ext)))
    return sorted(files)

# Сбор документов из Theory и Portfolio
theory_files = collect_files_from_folder(theory_path, supported_extensions) if os.path.exists(theory_path) else []
portfolio_files = collect_files_from_folder(portfolio_path, supported_extensions) if os.path.exists(portfolio_path) else []

all_kb_files = theory_files + portfolio_files

print("\nСтатистика по базе знаний:")
print(f"Документов в Theory: {len(theory_files)}")
print(f"Документов в Portfolio: {len(portfolio_files)}")
print(f"Всего документов: {len(all_kb_files)}")

print("\nПримеры найденных файлов:")
for file_path in all_kb_files[:10]:
    print("-", file_path)
# Out:
# Проверка папок базы знаний...
#
# [OK] Папка найдена: /content/drive/MyDrive/AI_Release_Guardian_MVP/Theory
# [OK] Папка найдена: /content/drive/MyDrive/AI_Release_Guardian_MVP/Portfolio
#
# Статистика по базе знаний:
# Документов в Theory: 5
# Документов в Portfolio: 27
# Всего документов: 32
#
# Примеры найденных файлов:
# - /content/drive/MyDrive/AI_Release_Guardian_MVP/Theory/Копия Modul_1_Urok_1_Issledovanie_produkta_i_dekompozitsia.pdf
# - /content/drive/MyDrive/AI_Release_Guardian_MVP/Theory/Копия Modul_1_Urok_4_Klassy_ekvivalentnosti_i_granichnye_znachenia.pdf
# - /content/drive/MyDrive/AI_Release_Guardian_MVP/Theory/Копия Теория тестирования бонус.docx
# - /content/drive/MyDrive/AI_Release_Guardian_MVP/Theory/проверка форм ввода.docx
# - /content/drive/MyDrive/AI_Release_Guardian_MVP/Theory/тестирование полей и форм.docx
# - /content/drive/MyDrive/AI_Release_Guardian_MVP/Portfolio/devtools.docx
# - /content/drive/MyDrive/AI_Release_Guardian_MVP/Portfolio/mysql.docx
# ...

# %%
# ==========================================================
# Проверка качества базы знаний
# ==========================================================
# Важно не только собрать документы, но и убедиться,
# что база знаний не пустая и содержит достаточный объём данных.
# ==========================================================

if len(all_kb_files) == 0:
    print("ВНИМАНИЕ: база знаний пуста. Проверьте содержимое папок Theory и Portfolio.")
elif len(all_kb_files) < 3:
    print("ПРЕДУПРЕЖДЕНИЕ: документов очень мало. Это может ухудшить качество retrieval.")
else:
    print("База знаний выглядит достаточной для демонстрации RAG-подхода.")
# Out:
# База знаний выглядит достаточной для демонстрации RAG-подхода.

# %% [markdown]
# # Создание RAG-индекса
#
# В проекте используется подход **Retrieval Augmented Generation (RAG)**.
#
# Смысл этого подхода заключается в том, что перед генерацией рекомендаций система сначала ищет релевантные документы в базе знаний, а затем передаёт найденный контекст языковой модели.
#
# В данном проекте RAG используется не как классический чат-бот, а как источник экспертного контекста для задач анализа интерфейсов.
#
# LLM получает рекомендации по QA-практикам и использует их при:
#
# - генерации тестовых сценариев
# - анализе UX/UI рисков
# - выявлении потенциальных баг-зон
#
# ---
#
# ## Почему используется RAG
#
# Использование RAG позволяет:
#
# - повысить точность рекомендаций
# - снизить вероятность галлюцинаций
# - привязать анализ к QA-домену
# - использовать проверенные практики тестирования
#
# Таким образом LLM выполняет reasoning на основе контекста из базы знаний.
#
# ---
#
# ## Этапы построения RAG-слоя
#
# 1. Загрузка документов из базы знаний
# 2. Разбиение документов на фрагменты
# 3. Построение эмбеддингов для каждого фрагмента
# 4. Создание векторного индекса
# 5. Настройка retriever для поиска релевантных фрагментов
#
# При запросе система извлекает наиболее релевантные фрагменты и передаёт их LLM в качестве контекста.
#
# ---
#
# ## Используемые технологии
#
# - **LlamaIndex** — построение RAG-индекса
# - **HuggingFace Embeddings** — генерация эмбеддингов
# - **sentence-transformers** — базовая модель эмбеддингов

# %%
# ==========================================================
# Создание RAG-индекса
# ==========================================================
# В этом блоке:
# 1. Загружаем документы базы знаний
# 2. Настраиваем модель эмбеддингов
# 3. Строим векторный индекс
# 4. Создаём retriever для дальнейшего поиска
# ==========================================================

from llama_index.core import SimpleDirectoryReader, VectorStoreIndex, Settings
from llama_index.embeddings.huggingface import HuggingFaceEmbedding

# Настройка модели эмбеддингов
print("Загрузка модели эмбеддингов...")
embed_model = HuggingFaceEmbedding(model_name=CONFIG["EMBEDDING_MODEL"])

# Передаём модель эмбеддингов в глобальные настройки LlamaIndex
Settings.embed_model = embed_model

print("Модель эмбеддингов успешно настроена:")
print(CONFIG["EMBEDDING_MODEL"])
# Out:
# Загрузка модели эмбеддингов...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# ...

# %%
# ==========================================================
# Загрузка документов базы знаний
# ==========================================================
# LlamaIndex может читать документы прямо из папок.
# Мы отдельно читаем Theory и Portfolio, затем объединяем их.
# ==========================================================

documents = []

# Загружаем Theory
if os.path.exists(theory_path):
    print("Загрузка документов из Theory...")
    theory_docs = SimpleDirectoryReader(theory_path).load_data()
    print(f"Загружено документов из Theory: {len(theory_docs)}")
    documents.extend(theory_docs)
else:
    print("Папка Theory не найдена")

# Загружаем Portfolio
if os.path.exists(portfolio_path):
    print("Загрузка документов из Portfolio...")
    portfolio_docs = SimpleDirectoryReader(portfolio_path).load_data()
    print(f"Загружено документов из Portfolio: {len(portfolio_docs)}")
    documents.extend(portfolio_docs)
else:
    print("Папка Portfolio не найдена")

print(f"\nВсего загружено документов: {len(documents)}")
# Out:
# Загрузка документов из Theory...
# Загружено документов из Theory: 60
# Загрузка документов из Portfolio...
# Загружено документов из Portfolio: 27
#
# Всего загружено документов: 87

# %%
# ==========================================================
# Ограничение числа документов для ускорения Colab
# ==========================================================
# В учебной среде Colab слишком большой объём документов
# может замедлить построение индекса.
# Поэтому используем ограничение из CONFIG.
# ==========================================================

if len(documents) > CONFIG["MAX_DOCUMENTS"]:
    documents = documents[:CONFIG["MAX_DOCUMENTS"]]
    print(f"Количество документов ограничено до {CONFIG['MAX_DOCUMENTS']} для ускорения работы.")

print(f"Документов будет использовано для индексации: {len(documents)}")
# Out:
# Документов будет использовано для индексации: 87

# %%
# ==========================================================
# Построение векторного индекса
# ==========================================================
# Индекс позволяет искать релевантные документы
# по смыслу, а не только по ключевым словам.
# ==========================================================

print("Начинаем построение VectorStoreIndex...")

index = VectorStoreIndex.from_documents(documents)

print("VectorStoreIndex успешно создан.")
# Out:
# Начинаем построение VectorStoreIndex...
# VectorStoreIndex успешно создан.

# %%
# ==========================================================
# Создание retriever
# ==========================================================
# Retriever — это объект, который будет искать
# наиболее релевантные фрагменты документов.
# ==========================================================

retriever = index.as_retriever(
    similarity_top_k=CONFIG["TOP_K_RETRIEVAL"]
)

print("Retriever успешно создан.")
print(f"Параметр similarity_top_k = {CONFIG['TOP_K_RETRIEVAL']}")
# Out:
# Retriever успешно создан.
# Параметр similarity_top_k = 3

# %% [markdown]
# # **Фильтрация retrieval-контекста**
#
# После извлечения фрагментов из базы знаний система выполняет дополнительную фильтрацию контекста.
# Это позволяет уменьшить шум retrieval, убрать слишком общие фрагменты и передавать LLM только наиболее полезную информацию.

# %%
# ==========================================================
# CONTEXT FILTERING FOR RAG
# ==========================================================

def filter_retrieved_context(
    nodes,
    max_total_chars=1500,
    min_text_len=80,
    max_chunk_len=1400
):
    """
    Фильтрует retrieved nodes перед передачей в LLM.

    Логика:
    - убирает слишком короткие фрагменты
    - пытается убрать слишком общие QA-фрагменты
    - ограничивает общий размер контекста
    - если всё отфильтровалось, возвращает fallback-контекст
    """

    filtered_chunks = []
    total_chars = 0

    GENERIC_PATTERNS = [
        "кто такой тестировщик",
        "что такое тестирование",
        "миф о профессии",
        "защитник качества",
        "test plan identifier",
        "features to be tested",
        "features not to be tested",
        "references",
        "approach",
        "testlink",
        "execution type",
        "estimated exec. duration"
    ]

    for node in nodes:
        node_text = getattr(node, "text", None)

        if node_text is None and hasattr(node, "node"):
            node_text = getattr(node.node, "text", "")

        node_text = str(node_text).strip()

        if len(node_text) < min_text_len:
            continue

        lower_text = node_text.lower()

        # Если chunk слишком общий, но не весь состоит из мусора,
        # не выбрасываем его сразу полностью — просто пропускаем
        # только самые явно общие документы
        generic_hits = sum(pattern in lower_text for pattern in GENERIC_PATTERNS)

        if generic_hits >= 3:
            continue

        # Слишком длинные chunks режем, а не выбрасываем
        if len(node_text) > max_chunk_len:
            node_text = node_text[:max_chunk_len]

        if total_chars + len(node_text) > max_total_chars:
            remaining = max_total_chars - total_chars
            if remaining > min_text_len:
                filtered_chunks.append(node_text[:remaining])
            break

        filtered_chunks.append(node_text)
        total_chars += len(node_text)

    # ------------------------------------------------------
    # fallback: если всё отфильтровалось, берём первые
    # укороченные chunks без жёсткой фильтрации
    # ------------------------------------------------------
    if not filtered_chunks:
        fallback_chunks = []
        total_chars = 0

        for node in nodes:
            node_text = getattr(node, "text", None)

            if node_text is None and hasattr(node, "node"):
                node_text = getattr(node.node, "text", "")

            node_text = str(node_text).strip()

            if len(node_text) < min_text_len:
                continue

            node_text = node_text[:500]

            if total_chars + len(node_text) > max_total_chars:
                break

            fallback_chunks.append(node_text)
            total_chars += len(node_text)

        print("⚠️ Жёсткая фильтрация убрала весь контекст. Используется fallback-контекст.")
        return "\n\n".join(fallback_chunks)

    return "\n\n".join(filtered_chunks)

# %% [markdown]
# # Промежуточный вывод
#
# На данном этапе в проекте создан полноценный RAG-слой.
#
# Реализовано:
#
# - база знаний успешно загружена
# - документы преобразованы в векторное пространство
# - создан векторный индекс
# - настроен retriever для поиска релевантного контекста
#
# Таким образом система может извлекать релевантные фрагменты из базы знаний и передавать их языковой модели.
#
# Полученный контекст используется LLM при:
#
# - генерации тестовых сценариев
# - анализе интерфейса
# - выявлении потенциальных зон риска
#
# Это позволяет использовать **гибридную архитектуру Code + RAG + LLM reasoning**, где:
#
# - код извлекает факты из интерфейса
# - RAG предоставляет экспертные знания
# - LLM выполняет аналитическую интерпретацию данных

# %% [markdown]
# # Трассировка работы RAG-системы
#
# Ниже приведена пошаговая трассировка работы RAG-подхода в проекте **AI Release Guardian** на примере поля ввода пароля.
#
# Цель трассировки — показать, как система:
#
# - получает описание UI-элемента из интерфейса страницы
# - формирует запрос к базе знаний
# - извлекает релевантный QA-контекст
# - подготавливает данные для дальнейшего LLM-анализа
#
# Такая трассировка позволяет продемонстрировать, что система использует **grounded RAG-подход**: контекст извлекается не произвольно, а на основе конкретного элемента интерфейса.
#
# Это важно для снижения вероятности галлюцинаций, поскольку LLM опирается на:
#
# - реальные данные DOM-анализа
# - извлечённые документы базы знаний
# - структурированные входные данные

# %%
# ==========================================================
# RAG TRACE DEMO — шаг 1
# Демонстрационный UI-объект
# ==========================================================
# В качестве примера используем поле ввода пароля.
# Это позволит показать, как система работает
# с конкретным тестируемым элементом интерфейса.
# ==========================================================

print("STEP 1 — DEMO UI OBJECT\n")

sample_object = {
    "type": "input",
    "name": "password",
    "label": "Пароль",
    "placeholder": "Введите пароль",
    "locator": "#password",
    "text": ""
}

print("Демонстрационный объект:")
for key, value in sample_object.items():
    print(f"{key}: {value}")
# Out:
# STEP 1 — DEMO UI OBJECT
#
# Демонстрационный объект:
# type: input
# name: password
# label: Пароль
# placeholder: Введите пароль
# locator: #password
# text:

# %%
# ==========================================================
# RAG TRACE DEMO — шаг 2
# Формирование запроса к базе знаний
# ==========================================================
# На этом этапе мы превращаем структурированное описание
# UI-элемента в текстовый запрос для retrieval.
# ==========================================================

print("\nSTEP 2 — QUERY GENERATION\n")

rag_query = f"""
UI element type: {sample_object['type']}
Name: {sample_object['name']}
Label: {sample_object['label']}
Placeholder: {sample_object['placeholder']}
Locator: {sample_object['locator']}

Какие тесты, проверки и риски следует учитывать для данного элемента интерфейса?
"""

print("Сформированный запрос к базе знаний:")
print(rag_query)
# Out:
# STEP 2 — QUERY GENERATION
#
# Сформированный запрос к базе знаний:
#
# UI element type: input
# Name: password
# Label: Пароль
# Placeholder: Введите пароль
# Locator: #password
#
# Какие тесты, проверки и риски следует учитывать для данного элемента интерфейса?

# %% [markdown]
# # Улучшение RAG: расширение запроса (Query Enrichment)
#
# Чтобы повысить точность retrieval, запрос к базе знаний расширяется
# дополнительными QA-терминами.
#
# Это позволяет retriever находить более релевантные рекомендации
# по тестированию интерфейсных элементов.

# %%
# ==========================================================
# RAG QUERY ENRICHMENT
# ==========================================================

QA_TERMS = [
    "валидация поля",
    "негативные сценарии",
    "граничные значения",
    "пограничные случаи",
    "проверка ошибок",
    "поведение интерфейса",
    "валидация формы",
    "проверка ввода пользователя"
]

def enrich_query(base_query, element_type=None):
    """
    Расширяет запрос к базе знаний для улучшения retrieval.
    Делает запрос более узким и ориентированным на тестирование UI-элемента.
    """

    terms = ", ".join(QA_TERMS)

    if element_type:
        enriched = (
            f"{base_query}\n\n"
            f"Сфокусируйся на рекомендациях по тестированию элемента интерфейса типа: {element_type}. "
            f"Приоритет отдавай проверкам валидации поля, негативным сценариям, "
            f"граничным значениям, поведению интерфейса и обработке ошибок. "
            f"Игнорируй общие тест-планы и бизнес-сценарии вроде корзины, заказов, "
            f"подарочных карт или профилей пользователей. "
            f"Используй подходы QA: {terms}."
        )
    else:
        enriched = (
            f"{base_query}\n\n"
            f"Сфокусируйся на рекомендациях по тестированию элементов интерфейса. "
            f"Предпочитай советы по валидации ввода, негативным сценариям, "
            f"граничным значениям и проверкам UI-поведения. "
            f"Игнорируй общие тест-планы бизнес-систем. "
            f"Используй QA-подходы: {terms}."
        )

    return enriched

# %% [markdown]
# # Улучшение RAG: фильтрация результатов retrieval
#
# Некоторые найденные фрагменты могут быть слабо релевантными.
#
# Поэтому используется дополнительная фильтрация результатов
# по score similarity.

# %%
# ==========================================================
# SCORE FILTERING
# ==========================================================

SIMILARITY_THRESHOLD = 0.1

def filter_by_score(nodes):
    """
    Отсеивает слишком слабые retrieval results по score.
    Если после фильтрации список пуст, возвращает исходные nodes.
    """

    filtered = []

    for node in nodes:
        score = getattr(node, "score", None)

        if score is None:
            filtered.append(node)
            continue

        if score >= SIMILARITY_THRESHOLD:
            filtered.append(node)

    # Если всё отфильтровалось, возвращаем исходный список
    if not filtered:
        print("⚠️ Все узлы были отфильтрованы по score. Возвращаем исходные retrieval results.")
        return nodes

    return filtered

# %% [markdown]
# # Улучшение RAG: простой reranking контекста
#
# После retrieval применяется дополнительная сортировка контекста
# по наличию QA-ключевых слов.
#
# Это помогает поднимать более полезные рекомендации выше
# в передаваемом контексте.

# %%
# ==========================================================
# LIGHT RERANKING
# ==========================================================

QA_KEYWORDS = [
    "валидация поля",
    "негативные сценарии",
    "граничные значения",
    "пограничные случаи",
    "проверка ошибок",
    "поведение интерфейса",
    "валидация формы",
    "проверка ввода пользователя"
]

def rerank_nodes(nodes):

    def score_node(node):
        text = getattr(node, "text", "").lower()

        score = 0
        for kw in QA_KEYWORDS:
            if kw in text:
                score += 1

        return score

    ranked = sorted(nodes, key=score_node, reverse=True)

    return ranked

# %%
# ==========================================================
# RAG TRACE DEMO — шаг 3
# ==========================================================

enriched_query_text = enrich_query(rag_query)

retrieved_nodes = retriever.retrieve(enriched_query_text)

retrieved_nodes = filter_by_score(retrieved_nodes)

retrieved_nodes = rerank_nodes(retrieved_nodes)

print(f"Количество найденных фрагментов: {len(retrieved_nodes)}")
# Out:
# Количество найденных фрагментов: 3

# %%
# ==========================================================
# RAG TRACE DEMO — шаг 4
# Просмотр найденного контекста
# ==========================================================
# Здесь мы выводим несколько найденных фрагментов,
# чтобы увидеть, какой контекст система будет передавать LLM.
# ==========================================================

print("\nSTEP 4 — RETRIEVED CONTEXT\n")

for i, node in enumerate(retrieved_nodes[:CONFIG["TOP_K_RETRIEVAL"]], start=1):
    print("=" * 80)
    print(f"Фрагмент контекста #{i}")
    print("=" * 80)

    # У разных версий узлов текст может лежать в разных полях.
    # Поэтому используем безопасное извлечение текста.
    node_text = getattr(node, "text", None)
    if node_text is None and hasattr(node, "node"):
        node_text = getattr(node.node, "text", "")

    print(str(node_text)[:1500])
    print("\n")
# Out:
# STEP 4 — RETRIEVED CONTEXT
#
# ...
# Фрагмент контекста #1
# ...
# Примеры тест-кейсов для проверки текстовых полей
#
# Текстовое поле — элемент графического интерфейса пользователя (GUI), предназначенный для ввода данных пользователем.
#
# Текстовые поля стали стандартной частью каждого сайта. Однако, именно в них часто встречаются ошибки, связанные с юзабилити, а для эффективного тестирования текстовых полей необходимо чётко понимать назначение каждого из них.
#
# На собеседовании кандидату часто задаётся вопрос, касающийся проверки корректности работы текстовых полей. Например: «Перечислите варианты тест-кейсов для поля “Имя”».
#
# В этой статье мы рассмотрим различные сценарии для тестирования текстовых полей и областей (включая числовые и обязательные поля). Статья поможет понять, как должны быть спроектированы текстовые поля и что нужно сделать, чтобы они были действительно удобными для использования.
#
# Содержание
#
# Тестирование текстового поля
#
# Типы текстовых полей
#
# ...

# %%
# ==========================================================
# RAG TRACE DEMO — шаг 5
# Подготовка контекста для LLM-анализа
# ==========================================================
# На этом этапе найденные фрагменты проходят дополнительную
# фильтрацию, чтобы уменьшить шум retrieval и передать LLM
# только наиболее полезный контекст.
# ==========================================================

print("\nSTEP 5 — CONTEXT ASSEMBLY\n")

retrieved_context = filter_retrieved_context(retrieved_nodes)

print("Собранный контекст для LLM после фильтрации:")
print(retrieved_context[:3000])
# Out:
# STEP 5 — CONTEXT ASSEMBLY
#
# Собранный контекст для LLM после фильтрации:
# Примеры тест-кейсов для проверки текстовых полей
#
# Текстовое поле — элемент графического интерфейса пользователя (GUI), предназначенный для ввода данных пользователем.
#
# Текстовые поля стали стандартной частью каждого сайта. Однако, именно в них часто встречаются ошибки, связанные с юзабилити, а для эффективного тестирования текстовых полей необходимо чётко понимать назначение каждого из них.
#
# На собеседовании кандидату часто задаётся вопрос, касающийся проверки корректности работы текстовых полей. Например: «Перечислите варианты тест-кейсов для поля “Имя”».
#
# В этой статье мы рассмотрим различные сценарии для тестирования текстовых полей и областей (включая числовые и обязательные поля). Статья поможет понять, как должны быть спроектированы текстовые поля и что нужно сделать, чтобы они были действительно удобными для использования.
#
# Содержание
#
# Тестирование текстового поля
#
# ...

# %% [markdown]
# # Наблюдение по качеству retrieval
#
# В ходе трассировки работы RAG-системы видно, что извлечённый контекст частично содержит общие материалы по тестированию, а не только узкоспециализированные рекомендации для поля ввода пароля.
#
# Это демонстрирует одно из типичных ограничений RAG-подхода.
#
# Если база знаний содержит большое количество общих документов, а запрос сформулирован достаточно кратко, retriever может вернуть слишком широкий контекст.
#
# В результате LLM может получать смесь:
#
# - релевантных рекомендаций
# - общих материалов по тестированию
#
# Это может снижать точность рекомендаций.
#
# ---
#
# ## Реализованное улучшение retrieval
#
# Для уменьшения этой проблемы в проекте используется дополнительная фильтрация retrieval-контекста перед передачей его в LLM.
#
# Функция `filter_retrieved_context(...)` выполняет:
#
# - ограничение общего размера контекста
# - отсев слишком коротких фрагментов
# - удаление слишком общих материалов из базы знаний
#
# Это позволяет уменьшить шум retrieval и передавать языковой модели более релевантную информацию.
#
# ---
#
# ## Дополнительные направления улучшения
#
# В дальнейшем retrieval можно дополнительно улучшить за счёт:
#
# - более точной формулировки запросов к базе знаний
# - более строгой структуры базы знаний
# - добавления узкоспециализированных QA-документов
# - использования reranking для сортировки результатов
#
# Такие методы позволяют ещё сильнее повысить точность retrieval и уменьшить шум в передаваемом контексте.

# %% [markdown]
# База знаний содержит преимущественно общие материалы по тестированию.
# Поэтому retriever возвращает фрагменты, которые релевантны по смыслу, но не всегда содержат специализированные рекомендации для конкретного UI-элемента.
#
# Это демонстрирует одно из типичных ограничений RAG-подхода:
# если база знаний состоит в основном из общих документов, извлечённый контекст может быть слишком широким и содержать менее точные рекомендации для конкретной задачи.

# %% [markdown]
# # Выбор целевой страницы для анализа
#
# Система позволяет анализировать различные веб-страницы.
#
# Целевая страница задаётся через параметр **TARGET_URL**.
#
# Для повышения гибкости проекта URL можно:
#
# - взять из конфигурации по умолчанию
# - задать вручную перед запуском анализа
#
# Это делает систему более универсальной и позволяет запускать анализ для разных веб-интерфейсов.
#
# ---
#
# ## Повторные запуски анализа
#
# Каждый запуск анализа выполняется независимо и сохраняется как отдельный **run**.
#
# Это позволяет:
#
# - анализировать разные страницы
# - повторно запускать анализ одного сайта
# - сравнивать результаты между запусками
# - отслеживать изменения интерфейса

# %%
# ==========================================================
# Выбор целевого URL для анализа
# ==========================================================
# Пользователь может:
# 1. использовать URL по умолчанию из CONFIG
# 2. ввести другой URL вручную
# ==========================================================

default_url = CONFIG["DEFAULT_TARGET_URL"]

user_url = input(
    f"Введите URL для анализа или нажмите Enter для значения по умолчанию\n[{default_url}]: "
).strip()

if user_url:
    TARGET_URL = user_url
    print("Используется пользовательский URL:")
else:
    TARGET_URL = default_url
    print("Используется URL по умолчанию:")

print(TARGET_URL)
# Out:
# Введите URL для анализа или нажмите Enter для значения по умолчанию
# [https://trainer.sedtest-tools.ru/checkpass/]:
# Используется URL по умолчанию:
# https://trainer.sedtest-tools.ru/checkpass/

# %% [markdown]
# # Run-based архитектура анализа
#
# AI Release Guardian сохраняет результаты анализа сайта в виде отдельных **runs**.
#
# Каждый запуск анализа создаёт новую папку, содержащую артефакты анализа интерфейса.
#
# В run сохраняются:
#
# - HTML страницы
# - testable objects
# - сгенерированные тестовые сценарии
# - результаты AI-анализа
# - отчёты об изменениях интерфейса
# - итоговая сводка анализа
#
# Такая структура позволяет сохранять состояние анализа на момент запуска.
#
# ---
#
# ## Преимущества run-based архитектуры
#
# Использование отдельных run-папок позволяет:
#
# - хранить историю анализа интерфейса
# - сравнивать версии страницы между запусками
# - выявлять изменения интерфейса (UI diff)
# - анализировать потенциальные регрессии
#
# Таким образом система может использовать предыдущие результаты анализа для оценки рисков при выпуске новых версий интерфейса.

# %%
# ==========================================================
# RUN ARCHITECTURE
# ==========================================================
# Каждый запуск анализа сохраняется в отдельную папку
# внутри Google Drive.
# Это позволяет хранить историю анализов сайта
# между сессиями Colab.
# ==========================================================

import os
import re
from urllib.parse import urlparse

def make_safe_site_name(url: str) -> str:
    """
    Преобразует URL сайта в безопасное имя папки.
    """
    parsed = urlparse(url)
    raw_name = parsed.netloc or "unknown_site"
    safe_name = raw_name.replace(".", "_").replace(":", "_")
    return safe_name

# TARGET_URL уже выбран на предыдущем шаге
site_name = make_safe_site_name(TARGET_URL)

print("Сайт:", site_name)

# Корневая папка для run-артефактов в Google Drive
sites_root = CONFIG["RUNS_ROOT"]

# Папка конкретного сайта
site_dir = os.path.join(sites_root, site_name)

# Папка всех запусков
runs_dir = os.path.join(site_dir, "runs")

# Создаём директории
os.makedirs(runs_dir, exist_ok=True)

# Ищем уже существующие run
existing_runs = [
    d for d in os.listdir(runs_dir)
    if re.match(r"run_\d{3}$", d)
]

# Определяем следующий номер run
if len(existing_runs) == 0:
    run_number = 1
else:
    run_numbers = [int(r.split("_")[1]) for r in existing_runs]
    run_number = max(run_numbers) + 1

current_run_name = f"run_{run_number:03d}"
run_dir = os.path.join(runs_dir, current_run_name)

os.makedirs(run_dir, exist_ok=True)

# Все артефакты текущего запуска будут сохраняться сюда
artifacts_dir = run_dir

print("Создан новый run:")
print(run_dir)
# Out:
# Сайт: trainer_sedtest-tools_ru
# Создан новый run:
# /content/drive/MyDrive/AI_Release_Guardian_MVP/Sites/trainer_sedtest-tools_ru/runs/run_009

# %% [markdown]
# # DOM-анализ веб-страницы
#
# В отличие от классических RAG-ассистентов, которые работают только с текстовыми документами, система **AI Release Guardian** анализирует реальный интерфейс веб-страницы.
#
# На этом этапе система выполняет **извлечение фактов из интерфейса**, которые затем используются языковой моделью для аналитических задач.
#
# Процесс включает несколько шагов:
#
# 1. открытие страницы в браузере
# 2. получение HTML-кода страницы
# 3. извлечение структуры DOM
# 4. подготовку данных для дальнейшей декомпозиции интерфейса
#
# Таким образом код извлекает структурированную информацию о странице, а LLM выполняет reasoning на основе этих данных.
#
# ---
#
# ## Почему используется DOM-анализ
#
# DOM-анализ позволяет:
#
# - получить реальную структуру интерфейса
# - обнаружить элементы UI
# - подготовить **testable objects** для анализа
#
# Это снижает вероятность галлюцинаций, поскольку модель работает с реальными элементами страницы, а не с предполагаемым интерфейсом.
#
# ---
#
# ## Используемые технологии
#
# Для анализа страницы используются:
#
# - **Selenium** — автоматизация браузера и загрузка страницы
# - **BeautifulSoup** — парсинг HTML и анализ структуры DOM

# %% [markdown]
# ## Использование облачного браузера
#
# Для выполнения DOM-анализа используется облачная инфраструктура **LambdaTest**.
#
# Это позволяет запускать браузер в удалённой среде и выполнять анализ веб-страницы без необходимости установки локального браузера.
#
# Такой подход обеспечивает:
#
# - стабильную загрузку страниц
# - воспроизводимость экспериментов
# - независимость от локальной среды выполнения
#
# ---
#
# ## Безопасное подключение
#
# Чтобы не хранить учетные данные в коде, система запрашивает при запуске ячейки:
#
# - **LambdaTest Username**
# - **LambdaTest Access Key**
#
# Учетные данные вводятся вручную и используются только для текущей сессии.
#
# Это позволяет избежать хранения чувствительной информации в коде проекта.

# %%
# ==========================================================
# Ввод LambdaTest credentials
# ==========================================================
# Для безопасности учетные данные не хранятся в коде.
# Пользователь вводит их при запуске ячейки.
# ==========================================================

from getpass import getpass

LT_USERNAME = input("Введите LambdaTest username: ")
LT_ACCESS_KEY = getpass("Введите LambdaTest access key: ")

print("Credentials получены")
# Out:
# Введите LambdaTest username: stasikent
# Введите LambdaTest access key: ··········
# Credentials получены

# %% [markdown]
# Используется **Selenium 4**, при этом параметры подключения к удалённому браузеру передаются через **Options API (capabilities)**.
#
# Такой подход соответствует современному API Selenium и позволяет корректно подключаться к удалённым браузерам, включая облачные инфраструктуры тестирования, такие как LambdaTest.

# %%
# ==========================================================
# Подключение к LambdaTest Selenium Grid (Selenium 4)
# ==========================================================

from selenium import webdriver
from selenium.webdriver.chrome.options import Options

GRID_URL = f"https://{LT_USERNAME}:{LT_ACCESS_KEY}@hub.lambdatest.com/wd/hub"

chrome_options = Options()

# LambdaTest capabilities
chrome_options.set_capability("browserName", "Chrome")
chrome_options.set_capability("browserVersion", "latest")

chrome_options.set_capability("LT:Options", {
    "platformName": "Windows 11",
    "build": "AI Release Guardian",
    "name": "DOM Analysis Session"
})

print("Подключаемся к LambdaTest...")

driver = webdriver.Remote(
    command_executor=GRID_URL,
    options=chrome_options
)

print("Соединение с LambdaTest установлено")
# Out:
# Подключаемся к LambdaTest...
# /usr/local/lib/python3.12/dist-packages/selenium/webdriver/remote/remote_connection.py:421: UserWarning: Embedding username and password in URL could be insecure, use ClientConfig instead
#   headers = self.get_remote_connection_headers(parsed_url, self._client_config.keep_alive)
# Соединение с LambdaTest установлено

# %%
# ==========================================================
# Открытие страницы для DOM анализа
# ==========================================================

import time

print("Открываем страницу:", TARGET_URL)

driver.get(TARGET_URL)

time.sleep(3)

print("Страница успешно загружена")
# Out:
# Открываем страницу: https://trainer.sedtest-tools.ru/checkpass/
# Страница успешно загружена

# %%
# ==========================================================
# Получение HTML страницы
# ==========================================================

page_html = driver.page_source

print("HTML страницы получен")
print("Размер HTML:", len(page_html))
# Out:
# HTML страницы получен
# Размер HTML: 71761

# %% [markdown]
# ### Скриншот анализируемой страницы
#
# Для наглядности сохраняется скриншот страницы, которая анализируется системой.
# Это позволяет визуально сопоставить структуру интерфейса с результатами DOM-анализа.

# %%
# ==========================================================
# SCREENSHOT TRACE — анализируемая страница
# ==========================================================

screenshot_path = os.path.join(run_dir, "page_screenshot.png")

driver.save_screenshot(screenshot_path)

print("Скриншот страницы сохранён:")
print(screenshot_path)
# Out:
# Скриншот страницы сохранён:
# /content/drive/MyDrive/AI_Release_Guardian_MVP/Sites/trainer_sedtest-tools_ru/runs/run_009/page_screenshot.png

# %%
# ==========================================================
# Завершение Selenium сессии
# ==========================================================

driver.quit()

print("Сессия LambdaTest завершена")
# Out:
# Сессия LambdaTest завершена

# %% [markdown]
# ### Наглядность DOM-анализа
#
# Ниже выводится фрагмент HTML-структуры страницы, полученной системой.
# Это демонстрирует, какие данные используются для декомпозиции интерфейса.

# %%
# ==========================================================
# DOM TRACE
# ==========================================================

print("Фрагмент DOM страницы:\n")

print(page_html[:2000])
# Out:
# Фрагмент DOM страницы:
#
# <html lang="ru"><head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#
#     <title>Тренажер: Проверка пароля</title>
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#             background: #f7f7f9;
#             margin: 0;
#             padding: 0;
#         }
#
#         .container {
#             max-width: 90%;
#             margin: 30px auto;
#             display: flex;
#             background: #fff;
#             border-radius: 16px;
#             box-shadow: 0 4px 24px rgba(0, 0, 0, 0.07);
#         }
#
#         .cases {
#             width: 50%;
#             background: #f4f5fa;
#             padding: 24px 20px 24px 32px;
#             border-top-left-radius: 16px;
#             border-bottom-left-radius: 16px;
#             min-height: 470px;
#             display: flex;
#             flex-direction: column;
# ...

# %% [markdown]
# # Декомпозиция интерфейса на testable objects
#
# После получения HTML страницы необходимо перейти от сырого DOM к более удобному представлению интерфейса.
#
# Для этого в проекте используется слой **testable objects** — нормализованных объектов интерфейса, пригодных для тестирования и дальнейшего AI-анализа.
#
# ---
#
# ## Зачем нужна декомпозиция
#
# Сырой HTML неудобно напрямую передавать в LLM, потому что:
#
# - в нём содержится большое количество служебной информации
# - элементы представлены в низкоуровневом виде
# - анализ становится менее устойчивым
#
# Поэтому система выполняет **нормализацию DOM** и переводит элементы страницы в структурированные тестируемые сущности.
#
# ---
#
# ## Примеры testable objects
#
# К таким объектам относятся:
#
# - поле ввода
# - кнопка
# - чекбокс
# - радиокнопка
# - таблица
# - изображение
# - ссылка
# - другие интерактивные элементы интерфейса
#
# ---
#
# ## Классы эквивалентности элементов
#
# После извлечения элементов система группирует их по типам интерфейсных объектов.
#
# Например:
#
# - все кнопки
# - все поля ввода
# - все ссылки
#
# Элементы одного типа обычно тестируются **по одинаковым принципам**, поэтому они рассматриваются как **класс эквивалентности**.
#
# Для генерации тестов выбирается **representative element** — один типичный представитель группы.
#
# Это позволяет:
#
# - сократить объём генерации тестов
# - избежать дублирования
# - сохранить покрытие основных сценариев тестирования.
#
# ---
#
# ## Что происходит на этом этапе
#
# На этапе декомпозиции выполняются следующие действия:
#
# - выделение основных типов элементов из DOM
# - извлечение полезных атрибутов элементов
# - формирование нормализованного списка testable objects
# - группировка элементов по типам
# - подготовка summary по странице

# %%
# ==========================================================
# Декомпозиция DOM → testable objects
# ==========================================================
# В этом блоке:
# 1. Используем уже полученный HTML страницы
# 2. Парсим его через BeautifulSoup
# 3. Извлекаем тестируемые элементы интерфейса
# 4. Приводим их к единой нормализованной структуре
# ==========================================================

from bs4 import BeautifulSoup
import json
import os

# Повторно парсим HTML, если soup ещё не создан
soup = BeautifulSoup(page_html, "html.parser")

print("DOM готов к декомпозиции")
# Out:
# DOM готов к декомпозиции

# %%
# ==========================================================
# Вспомогательные функции для извлечения атрибутов
# ==========================================================

def safe_get_attr(tag, attr_name, default=""):
    """
    Безопасно получает значение атрибута HTML-тега.

    Аргументы:
        tag: объект BeautifulSoup tag
        attr_name (str): имя атрибута
        default (str): значение по умолчанию

    Возвращает:
        str: значение атрибута или default
    """
    if tag is None:
        return default
    return tag.attrs.get(attr_name, default)


def normalize_text(value):
    """
    Нормализует текст:
    - убирает лишние пробелы
    - приводит None к пустой строке

    Аргументы:
        value: входное значение

    Возвращает:
        str: очищенный текст
    """
    if value is None:
        return ""
    return " ".join(str(value).split()).strip()


def build_display_name(obj):
    """
    Формирует человекочитаемое имя объекта.
    Используется для отображения в интерфейсе и отчётах.
    """
    candidates = [
        obj.get("label", ""),
        obj.get("name", ""),
        obj.get("id", ""),
        obj.get("placeholder", ""),
        obj.get("text", ""),
        obj.get("locator", "")
    ]

    for item in candidates:
        item = normalize_text(item)
        if item:
            return item

    return f"{obj.get('object_type', 'unknown_object')}_{obj.get('index', 0)}"

# %%
# ==========================================================
# Контейнер для testable objects
# ==========================================================

testable_objects = []

def add_object(object_type, tag, index, extra=None):
    """
    Добавляет нормализованный объект интерфейса в общий список.

    Аргументы:
        object_type (str): тип объекта (input, button и т.д.)
        tag: HTML-тег BeautifulSoup
        index (int): порядковый индекс объекта
        extra (dict): дополнительные поля
    """
    obj = {
        "index": index,
        "object_type": object_type,
        "tag_name": tag.name if tag else "",
        "id": normalize_text(safe_get_attr(tag, "id")),
        "name": normalize_text(safe_get_attr(tag, "name")),
        "type": normalize_text(safe_get_attr(tag, "type")),
        "class": " ".join(tag.get("class", [])) if tag and tag.get("class") else "",
        "placeholder": normalize_text(safe_get_attr(tag, "placeholder")),
        "value": normalize_text(safe_get_attr(tag, "value")),
        "text": normalize_text(tag.get_text(" ", strip=True) if tag else ""),
        "aria_label": normalize_text(safe_get_attr(tag, "aria-label")),
        "title": normalize_text(safe_get_attr(tag, "title")),
        "href": normalize_text(safe_get_attr(tag, "href")),
        "src": normalize_text(safe_get_attr(tag, "src")),
        "locator": ""
    }

    # Простейший CSS-подобный locator для удобства анализа
    if obj["id"]:
        obj["locator"] = f"#{obj['id']}"
    elif obj["name"]:
        obj["locator"] = f'[name="{obj["name"]}"]'
    else:
        obj["locator"] = tag.name if tag else "unknown"

    # Дополнительные поля, если они есть
    if extra:
        obj.update(extra)

    # Формируем display_name после заполнения полей
    obj["display_name"] = build_display_name(obj)

    testable_objects.append(obj)

# %%
# ==========================================================
# Извлечение input-элементов
# ==========================================================
# Сюда входят:
# - text input
# - password input
# - email input
# - hidden, checkbox, radio и т.д.
# В дальнейшем checkbox и radio можно анализировать отдельно,
# но на этом шаге мы сначала собираем все input.
# ==========================================================

input_tags = soup.find_all("input")

for idx, tag in enumerate(input_tags, start=1):
    add_object("input", tag, idx)

print(f"Найдено input-элементов: {len(input_tags)}")
# Out:
# Найдено input-элементов: 1

# %%
# ==========================================================
# Извлечение button-элементов
# ==========================================================

button_tags = soup.find_all("button")

for idx, tag in enumerate(button_tags, start=1):
    add_object("button", tag, idx)

print(f"Найдено button-элементов: {len(button_tags)}")
# Out:
# Найдено button-элементов: 4

# %%
# ==========================================================
# Извлечение form-элементов
# ==========================================================

form_tags = soup.find_all("form")

for idx, tag in enumerate(form_tags, start=1):
    add_object("form", tag, idx)

print(f"Найдено form-элементов: {len(form_tags)}")
# Out:
# Найдено form-элементов: 0

# %%
# ==========================================================
# Извлечение ссылок
# ==========================================================

link_tags = soup.find_all("a")

for idx, tag in enumerate(link_tags, start=1):
    add_object("link", tag, idx)

print(f"Найдено ссылок: {len(link_tags)}")
# Out:
# Найдено ссылок: 0

# %%
# ==========================================================
# Извлечение изображений
# ==========================================================

image_tags = soup.find_all("img")

for idx, tag in enumerate(image_tags, start=1):
    add_object("image", tag, idx)

print(f"Найдено изображений: {len(image_tags)}")
# Out:
# Найдено изображений: 1

# %%
# ==========================================================
# Извлечение таблиц
# ==========================================================

table_tags = soup.find_all("table")

for idx, tag in enumerate(table_tags, start=1):
    add_object("table", tag, idx)

print(f"Найдено таблиц: {len(table_tags)}")
# Out:
# Найдено таблиц: 0

# %%
# ==========================================================
# Дополнительная классификация input-элементов
# ==========================================================
# После первичного сбора input мы можем уточнить их тип.
# Это полезно для QA-анализа, потому что password, checkbox
# и radio требуют разных тестовых сценариев.
# ==========================================================

for obj in testable_objects:
    if obj["object_type"] == "input":
        input_type = obj.get("type", "").lower()

        if input_type == "checkbox":
            obj["object_type"] = "checkbox"
        elif input_type == "radio":
            obj["object_type"] = "radio"
        elif input_type == "password":
            obj["object_type"] = "password_input"
        elif input_type == "email":
            obj["object_type"] = "email_input"
        elif input_type == "hidden":
            obj["object_type"] = "hidden_input"

# %%
# ==========================================================
# Сводка по типам testable objects
# ==========================================================

from collections import Counter

object_type_counter = Counter(obj["object_type"] for obj in testable_objects)

print("Сводка по testable objects:\n")
for object_type, count in object_type_counter.items():
    print(f"{object_type}: {count}")

print(f"\nВсего testable objects: {len(testable_objects)}")
# Out:
# Сводка по testable objects:
#
# input: 1
# button: 4
# image: 1
#
# Всего testable objects: 6

# %%
# ==========================================================
# Просмотр первых testable objects
# ==========================================================
# Это помогает визуально проверить, что декомпозиция
# выполнена корректно.
# ==========================================================

print("Первые testable objects:\n")

for obj in testable_objects[:10]:
    print(json.dumps(obj, ensure_ascii=False, indent=2))
    print("-" * 80)
# Out:
# Первые testable objects:
#
# {
#   "index": 1,
#   "object_type": "input",
#   "tag_name": "input",
#   "id": "pass",
#   "name": "",
#   "type": "text",
#   "class": "",
#   "placeholder": "",
#   "value": "",
#   "text": "",
#   "aria_label": "",
#   "title": "",
#   "href": "",
#   "src": "",
#   "locator": "#pass",
#   "display_name": "pass"
# }
# --------------------------------------------------------------------------------
# {
#   "index": 1,
#   "object_type": "button",
#   "tag_name": "button",
#   "id": "showCasesBtn",
#   "name": "",
#   "type": "",
#   "class": "show-cases-btn",
#   "placeholder": "",
#   "value": "",
#   "text": "Показать все тест-кейсы",
#   "aria_label": "",
#   "title": "",
#   "href": "",
#   "src": "",
#   "locator": "#showCasesBtn",
#   "display_name": "showCasesBtn"
# }
# --------------------------------------------------------------------------------
# {
#   "index": 2,
#   "object_type": "button",
#   "tag_name": "button",
# ...

# %%
# ==========================================================
# Сохранение testable objects в JSON
# ==========================================================
# Сохраняем результат как отдельный артефакт анализа.
# ==========================================================

artifacts_dir = run_dir
os.makedirs(artifacts_dir, exist_ok=True)

testable_objects_path = os.path.join(artifacts_dir, "testable_objects.json")

with open(testable_objects_path, "w", encoding="utf-8") as f:
    json.dump(testable_objects, f, ensure_ascii=False, indent=2)

print("Testable objects сохранены:")
print(testable_objects_path)
# Out:
# Testable objects сохранены:
# /content/drive/MyDrive/AI_Release_Guardian_MVP/Sites/trainer_sedtest-tools_ru/runs/run_009/testable_objects.json

# %% [markdown]
# # Выбор representative elements по типам объектов
#
# После декомпозиции интерфейса система получает список **testable objects**.
#
# Многие элементы интерфейса относятся к одному и тому же типу (например, несколько кнопок или несколько полей ввода).
#
# Чтобы уменьшить дублирование тестов, элементы рассматриваются как **классы эквивалентности**.
#
# Элементы одного типа обычно тестируются по одинаковым принципам, поэтому нет необходимости генерировать отдельный набор тестов для каждого элемента.
#
# ---
#
# ## Representative element
#
# На этом этапе для каждого типа объектов выбирается один **representative element** — типичный представитель группы.
#
# Этот элемент используется для генерации тестовых сценариев для всего класса элементов.
#
# Например:

# %%
# ==========================================================
# Representative elements по типам объектов
# ==========================================================
# Эта ячейка:
# 1. Берёт уже существующий список testable_objects
# 2. Группирует элементы по object_type
# 3. Выбирает по одному representative element на каждый тип
#
# ВАЖНО:
# - старая логика selected_object НЕ меняется
# - testable_objects НЕ перезаписывается
# - мы только добавляем новый слой данных
# ==========================================================

from collections import defaultdict
import json

# Проверяем, что testable_objects уже существует
if "testable_objects" not in globals() or not testable_objects:
    raise Exception(
        "Список testable_objects не найден или пуст. "
        "Сначала выполни декомпозицию DOM."
    )

# Группировка объектов по типу
objects_by_type = defaultdict(list)

for obj in testable_objects:
    obj_type = obj.get("object_type", "unknown")
    objects_by_type[obj_type].append(obj)

# Выбор representative element:
# берём первый объект каждого типа
representative_objects = {}

for obj_type, objects in objects_by_type.items():
    representative_objects[obj_type] = objects[0]

print("Representative elements по типам объектов:\n")

for obj_type, obj in representative_objects.items():
    print(
        f"- {obj_type}: "
        f"{obj.get('display_name', '')} | "
        f"{obj.get('locator', '')}"
    )

print(f"\nВсего найдено типов объектов: {len(representative_objects)}")
# Out:
# Representative elements по типам объектов:
#
# - input: pass | #pass
# - button: showCasesBtn | #showCasesBtn
# - image: img | img
#
# Всего найдено типов объектов: 3

# %% [markdown]
# # Сохранение representative elements
#
# Representative elements сохраняются как отдельный артефакт запуска.
#
# Это позволяет:
#
# - использовать их в последующем AI-анализе
# - применять их для генерации тестовых сценариев
# - сохранять историю классов эквивалентности интерфейсных элементов
#
# ---
#
# ## Роль representative elements в системе
#
# Сохранение representative elements позволяет системе повторно использовать информацию о структуре интерфейса.
#
# В частности, эти данные могут использоваться для:
#
# - генерации тестов для типов элементов
# - анализа изменений интерфейса между запусками
# - воспроизводимости экспериментов
#
# Таким образом representative elements становятся важной частью **run-based архитектуры анализа**.

# %%
# ==========================================================
# Сохранение representative elements по типам объектов
# ==========================================================
# Эта ячейка:
# 1. Сохраняет representative_objects в текущую run-папку
# 2. Не меняет старые артефакты
# 3. Готовит базу для генерации тестов по типам
# ==========================================================

import os
import json

# Проверяем, что representative_objects уже существует
if "representative_objects" not in globals() or not representative_objects:
    raise Exception(
        "representative_objects не найден. "
        "Сначала выполни ячейку выбора representative elements."
    )

representative_objects_path = os.path.join(
    artifacts_dir,
    "representative_objects_by_type.json"
)

with open(representative_objects_path, "w", encoding="utf-8") as f:
    json.dump(representative_objects, f, ensure_ascii=False, indent=2)

print("Representative elements сохранены:")
print(representative_objects_path)
# Out:
# Representative elements сохранены:
# /content/drive/MyDrive/AI_Release_Guardian_MVP/Sites/trainer_sedtest-tools_ru/runs/run_009/representative_objects_by_type.json

# %% [markdown]
# # Генерация тестов для representative elements
#
# Для каждого типа интерфейсных объектов используется один **representative element**.
# На его основе система генерирует тестовые сценарии для всего класса эквивалентных элементов.
#
# Тесты формируются на основе:
#
# - структуры элемента интерфейса
# - рекомендаций из базы знаний QA-практик (RAG)
# - reasoning языковой модели
#
# Таким образом LLM выполняет анализ типичного элемента и предлагает тестовые сценарии, применимые ко всем элементам данного типа.
#
# ---
#
# ## Преимущества такого подхода
#
# Такой подход позволяет:
#
# - уменьшить дублирование тестов
# - покрыть все найденные типы объектов
# - приблизить систему к реальному тест-дизайну
# - сократить количество генераций LLM
#
# Это делает систему более эффективной и приближает её к практике **QA-тестирования на основе классов эквивалентности**.

# %%
# ==========================================================
# Проверка наличия VSEGPT API ключа
# ==========================================================

from getpass import getpass

if "VSEGPT_API_KEY" not in globals() or not VSEGPT_API_KEY:

    print("VSEGPT API ключ не найден.")
    VSEGPT_API_KEY = getpass("Введите VSEGPT API key: ")

    print("Ключ успешно установлен.")

else:
    print("VSEGPT API ключ уже установлен.")
# Out:
# VSEGPT API ключ не найден.
# Введите VSEGPT API key: ··········
# Ключ успешно установлен.

# %%
# ==========================================================
# Helper функция для вызова VSEGPT API
# ==========================================================

import requests

# ==========================================================
# Helper функция для вызова VSEGPT API
# ==========================================================

import requests

def call_vsegpt_api(system_prompt, user_prompt, model="openai/gpt-4o-mini"):

    url = "https://api.vsegpt.ru/v1/chat/completions"

    headers = {
        "Authorization": f"Bearer {VSEGPT_API_KEY}",
        "Content-Type": "application/json"
    }

    safe_system_prompt = safety_filter(system_prompt)
    safe_user_prompt = safety_filter(user_prompt)

    payload = {
        "model": model,
        "messages": [
            {"role": "system", "content": safe_system_prompt},
            {"role": "user", "content": safe_user_prompt}
        ],
        "temperature": 0.3
    }

    response = requests.post(url, headers=headers, json=payload)

    if response.status_code != 200:
        raise Exception(f"Ошибка VSEGPT API: {response.text}")

    data = response.json()

    return data["choices"][0]["message"]["content"]

# %% [markdown]
# **Безопасный слой обработки запросов**
#
# Перед передачей пользовательских или автоматически сформированных запросов в LLM система выполняет базовую фильтрацию.
# Это позволяет снизить риск prompt injection и некорректной интерпретации входных данных.

# %%
# ==========================================================
# SAFETY FILTER
# ==========================================================

ENABLE_SAFETY_FILTER = True

BLOCKED_PATTERNS = [
    "ignore previous instructions",
    "ignore all previous instructions",
    "system prompt",
    "reveal system prompt",
    "show hidden instructions",
    "delete all data",
    "execute code",
    "run shell",
    "os.system",
    "subprocess",
    "rm -rf",
]

def safety_filter(user_input: str) -> str:
    """
    Фильтрация prompt перед передачей в LLM.
    """

    if not ENABLE_SAFETY_FILTER:
        return user_input

    text = str(user_input).lower()

    for pattern in BLOCKED_PATTERNS:

        if pattern in text:

            print("⚠️ SAFETY FILTER TRIGGERED")
            print("Blocked pattern:", pattern)

            raise ValueError(
                f"Запрос заблокирован системой безопасности: найден '{pattern}'"
            )

    return user_input

# %%
# ==========================================================
# Генерация тестов для всех типов объектов
# ==========================================================
# Эта ячейка:
# 1. Проходит по representative_objects
# 2. Для каждого типа вызывает VSEGPT
# 3. Генерирует тесты для класса эквивалентных элементов
#
# ВАЖНО:
# - старая генерация для selected_object НЕ меняется
# - analysis_answer НЕ перезаписывается
# - это новый отдельный артефакт
# ==========================================================

import json

# Проверяем, что representative_objects уже существует
if "representative_objects" not in globals() or not representative_objects:
    raise Exception(
        "representative_objects не найден. "
        "Сначала выполни предыдущие ячейки."
    )

tests_by_type = {}

for obj_type, obj in representative_objects.items():

    type_prompt = f"""
Ты опытный QA-инженер.

Ниже приведён representative element для типа интерфейсных объектов.

Тип объекта: {obj_type}

Описание объекта:
{json.dumps(obj, ensure_ascii=False, indent=2)}

Сгенерируй тесты для данного типа элементов.

Нужны:
1. Основные позитивные тесты
2. Основные негативные тесты
3. UI / UX проверки
4. Граничные случаи
5. Что важно проверить для всех объектов этого типа

Требования:
- ответ на русском языке
- не выдумывай данные, которых нет во входе
- ориентируйся на класс элементов, а не только на один экземпляр
"""

    generated_tests = call_vsegpt_api(
        system_prompt=(
            "Ты опытный QA-инженер. "
            "Генерируй тесты для класса эквивалентных UI-элементов."
        ),
        user_prompt=type_prompt,
        model="openai/gpt-4o-mini"
    )

    tests_by_type[obj_type] = {
        "representative_object": obj,
        "generated_tests": generated_tests
    }

    print("=" * 80)
    print(f"Тип объекта: {obj_type}")
    print("=" * 80)
    print(generated_tests[:1200])
    print("\n")

print("Генерация тестов по типам завершена.")
# Out:
# ...
# Тип объекта: input
# ...
# ### 1. Основные позитивные тесты
#
# 1. **Тест на успешный ввод текста**:
#    - Описание: Ввести корректный текст в поле ввода и проверить, что значение поля соответствует введенному тексту.
#    - Шаги:
#      1. Ввести текст "Тестовый пароль" в поле ввода.
#      2. Проверить, что значение поля `value` равно "Тестовый пароль".
#
# 2. **Тест на пустое значение**:
#    - Описание: Проверить, что поле ввода может быть оставлено пустым.
#    - Шаги:
#      1. Убедиться, что поле ввода изначально пустое.
#      2. Проверить, что значение поля `value` равно "".
#
# 3. **Тест на наличие атрибута `id`**:
#    - Описание: Проверить, что элемент имеет атрибут `id` с правильным значением.
#    - Шаги:
#      1. Проверить, что атрибут `id` равен "pass".
#
# ### 2. Основные негативные тесты
#
# 1. **Тест на ввод недопустимых символов**:
#    - Описание: Проверить, что ввод недопустимых символов (например, специальных символов) не сохраняется.
#    - Шаги:
# ...

# %%
# ==========================================================
# Сохранение тестов по типам объектов
# ==========================================================
# Эта ячейка:
# 1. Сохраняет tests_by_type в текущую run-папку
# 2. Не трогает старый generated_test_cases.json
# 3. Добавляет новый артефакт для type-level test design
# ==========================================================

import os
import json

# Проверяем, что tests_by_type уже существует
if "tests_by_type" not in globals() or not tests_by_type:
    raise Exception(
        "tests_by_type не найден. "
        "Сначала выполни ячейку генерации тестов по типам."
    )

tests_by_type_path = os.path.join(
    artifacts_dir,
    "generated_test_cases_by_type.json"
)

with open(tests_by_type_path, "w", encoding="utf-8") as f:
    json.dump(tests_by_type, f, ensure_ascii=False, indent=2)

print("Тесты по типам сохранены:")
print(tests_by_type_path)
# Out:
# Тесты по типам сохранены:
# /content/drive/MyDrive/AI_Release_Guardian_MVP/Sites/trainer_sedtest-tools_ru/runs/run_009/generated_test_cases_by_type.json

# %% [markdown]
# # AI-анализ UI-объекта
#
# После декомпозиции интерфейса система получает список **testable objects**.
#
# Следующий шаг — выполнить интеллектуальный анализ одного **representative element**, представляющего класс эквивалентных интерфейсных объектов.
#
# На этом этапе система:
#
# - выбирает representative element
# - формирует запрос к базе знаний на основе его атрибутов
# - извлекает релевантный контекст через RAG
# - подготавливает prompt для LLM
# - получает рекомендации по тестированию
#
# Таким образом LLM выполняет reasoning на основе:
#
# - структуры интерфейса
# - рекомендаций из базы знаний
# - атрибутов UI-элемента.
#
# ---
#
# ## Почему анализ выполняется по объектам
#
# Поэлементный анализ позволяет:
#
# - анализировать интерфейс на уровне отдельных UI-компонентов
# - делать рекомендации более точными
# - связывать тесты с конкретным элементом интерфейса
# - уменьшать вероятность галлюцинаций
#
# Такой подход формирует **element-level анализ интерфейса**, который затем может использоваться при анализе всей страницы.

# %%
# ==========================================================
# Выбор объекта для AI-анализа
# ==========================================================
# Для демонстрации можно либо взять первый подходящий объект,
# либо выбрать password_input, если он есть на странице.
# ==========================================================

selected_object = None

# Сначала пытаемся найти наиболее интересный объект:
# поле пароля, email, обычный input или кнопку.
priority_types = ["password_input", "email_input", "input", "button", "form"]

for p_type in priority_types:
    for obj in testable_objects:
        if obj.get("object_type") == p_type:
            selected_object = obj
            break
    if selected_object is not None:
        break

# Если ничего не найдено — берём просто первый объект
if selected_object is None and len(testable_objects) > 0:
    selected_object = testable_objects[0]

if selected_object is None:
    raise Exception("Список testable_objects пуст. Невозможно выполнить AI-анализ.")

print("Выбранный объект для анализа:\n")
print(json.dumps(selected_object, ensure_ascii=False, indent=2))
# Out:
# Выбранный объект для анализа:
#
# {
#   "index": 1,
#   "object_type": "input",
#   "tag_name": "input",
#   "id": "pass",
#   "name": "",
#   "type": "text",
#   "class": "",
#   "placeholder": "",
#   "value": "",
#   "text": "",
#   "aria_label": "",
#   "title": "",
#   "href": "",
#   "src": "",
#   "locator": "#pass",
#   "display_name": "pass"
# }

# %%
# ==========================================================
# Формирование запроса к базе знаний по выбранному объекту
# ==========================================================
# Запрос строится на основе атрибутов DOM-объекта.
# Это важная часть grounded RAG-подхода:
# KB-запрос зависит от реального элемента интерфейса.
# ==========================================================

analysis_query = f"""
Элемент интерфейса для QA-анализа:

Тип объекта: {selected_object.get('object_type', '')}
HTML tag: {selected_object.get('tag_name', '')}
name: {selected_object.get('name', '')}
id: {selected_object.get('id', '')}
type: {selected_object.get('type', '')}
label: {selected_object.get('label', '')}
placeholder: {selected_object.get('placeholder', '')}
aria-label: {selected_object.get('aria_label', '')}
text: {selected_object.get('text', '')}
locator: {selected_object.get('locator', '')}

Нужны:
- рекомендации по тестированию
- позитивные проверки
- негативные проверки
- риски и уязвимые места
- UX-проверки, если они релевантны
"""

print("Сформированный запрос для retrieval:\n")
print(analysis_query)
# Out:
# Сформированный запрос для retrieval:
#
#
# Элемент интерфейса для QA-анализа:
#
# Тип объекта: input
# HTML tag: input
# name:
# id: pass
# type: text
# label:
# placeholder:
# aria-label:
# text:
# locator: #pass
#
# Нужны:
# - рекомендации по тестированию
# - позитивные проверки
# - негативные проверки
# - риски и уязвимые места
# - UX-проверки, если они релевантны

# %%
# ==========================================================
# Извлечение контекста из базы знаний
# ==========================================================

enriched_analysis_query = enrich_query(
    analysis_query,
    element_type=selected_object.get("object_type", "")
)

analysis_nodes = retriever.retrieve(enriched_analysis_query)
analysis_nodes = filter_by_score(analysis_nodes)
analysis_nodes = rerank_nodes(analysis_nodes)

print(f"Найдено фрагментов контекста после улучшенного retrieval: {len(analysis_nodes)}")
# Out:
# Найдено фрагментов контекста после улучшенного retrieval: 3

# %%
# ==========================================================
# Просмотр найденного контекста для выбранного объекта
# ==========================================================
# Сначала показываем несколько найденных фрагментов,
# затем формируем итоговый контекст через дополнительную
# фильтрацию retrieval-результатов.
# ==========================================================

print("Найденный контекст:\n")

for i, node in enumerate(analysis_nodes[:CONFIG["TOP_K_RETRIEVAL"]], start=1):
    node_text = getattr(node, "text", None)
    if node_text is None and hasattr(node, "node"):
        node_text = getattr(node.node, "text", "")

    node_text = str(node_text)[:1000]

    print("=" * 80)
    print(f"Контекст #{i}")
    print("=" * 80)
    print(node_text)
    print()

# ==========================================================
# Сборка итогового контекста для LLM
# ==========================================================

analysis_context = filter_retrieved_context(analysis_nodes)

print("Итоговый контекст для модели собран после фильтрации.")
print("Длина контекста:", len(analysis_context))
print(analysis_context[:2000])
# Out:
# Найденный контекст:
#
# ...
# Контекст #1
# ...
# В этом смысле туризм – сочетание кантовской свободы и татлинской (а для кого-то фуллеровской) структуры. То же говорим и о тестировании.
#
# Существует множество туристический метафор, помогающих нам в исследовательском тестировании и дополняющие freestyle. А это позволяет нам сделать тестирование быстрее и последовательнее. Вот они:
#
# Нет, еще не они. Важно понять, что функционал редко работает независимо от другого функционала. Они делятся ресурсами, обрабатывают общий ввод, и работают на тех же внутренних данных. Это значит, что тестирование функциональностей отдельно может исключить ошибки их взаимодействия.
#
# ...

# %% [markdown]
# # Демонстрация русскоязычной LLM
#
# В рамках проекта дополнительно демонстрируется использование локальной русскоязычной instruct-модели.
#
# Основная архитектура системы использует внешнюю LLM через VSEGPT API для выполнения аналитических задач.
# Локальная модель добавлена в проект как экспериментальный компонент, позволяющий показать возможность использования русскоязычных моделей для задач QA-анализа.
#
# Поскольку основная цель работы — продемонстрировать архитектуру нейро-сотрудника, локальная LLM используется в демонстрационном режиме на небольшом примере и не заменяет основной пайплайн анализа.

# %%
# ==========================================================
# Быстрая демонстрация русскоязычной LLM
# ==========================================================
# Важно:
# - используем короткий промпт
# - ограничиваем генерацию
# - не встраиваем модель во весь пайплайн
# ==========================================================

from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

ru_model_name = CONFIG["RU_LLM_MODEL"]

print("Начинаем загрузку русскоязычной модели...")

ru_tokenizer = AutoTokenizer.from_pretrained(ru_model_name)

ru_model = AutoModelForCausalLM.from_pretrained(
    ru_model_name,
    torch_dtype=torch.float16 if torch.cuda.is_available() else torch.float32,
    low_cpu_mem_usage=True
)

if torch.cuda.is_available():
    ru_model = ru_model.to("cuda")
    print("Модель перенесена на GPU")
else:
    print("GPU не найден, модель будет работать на CPU")

print("Русскоязычная модель загружена")
# Out:
# Начинаем загрузку русскоязычной модели...
# config.json:   0%|          | 0.00/731 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/605 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/613 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/338 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# GPU не найден, модель будет работать на CPU
# Русскоязычная модель загружена

# %%
# ==========================================================
# Демонстрация русскоязычной LLM
# ==========================================================
# Используем более жёсткий формат запроса,
# чтобы уменьшить вероятность "эхо-ответа".
# ==========================================================

demo_prompt = """
Ты опытный QA-инженер.

Задача:
Перечисли 5 тестов для поля ввода пароля на форме авторизации.

Требования к ответу:
- только список
- без пояснений
- каждый пункт с новой строки
- ответ на русском языке

Ответ:
"""

inputs = ru_tokenizer(demo_prompt, return_tensors="pt")

if torch.cuda.is_available():
    inputs = {k: v.to("cuda") for k, v in inputs.items()}

outputs = ru_model.generate(
    **inputs,
    max_new_tokens=120,
    temperature=0.2,
    do_sample=False,
    pad_token_id=ru_tokenizer.eos_token_id
)

generated_tokens = outputs[0][inputs["input_ids"].shape[1]:]
demo_answer = ru_tokenizer.decode(generated_tokens, skip_special_tokens=True)

print("Ответ модели:\n")
print(demo_answer)
# Out:
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Ответ модели:
#
# 1. Проверка наличия поля ввода пароля.
# 2. Проверка правильности форматирования поля ввода (например, наличие идентификатора).
# 3. Проверка доступности поля ввода при наличии ошибок.
# 4. Проверка отображения сообщения об ошибке при некорректном вводе.
# 5. Проверка возможности повторного ввода пароля.

# %% [markdown]
# # Результат генерации русскоязычной LLM
#
# В ходе эксперимента локальная русскоязычная модель успешно сгенерировала базовый набор тестов для поля ввода пароля.
#
# Несмотря на компактный размер модели, она смогла:
#
# - корректно распознать тип интерфейсного элемента
# - предложить несколько базовых тестовых проверок
# - сформировать ответ на русском языке
#
# Это демонстрирует, что локальные русскоязычные LLM могут использоваться для задач анализа интерфейса и генерации тестовых рекомендаций.
#
# При этом качество reasoning зависит от размера модели и сложности запроса, поэтому локальная модель используется в проекте как **экспериментальный компонент**, а основной анализ выполняется через внешнюю LLM.

# %% [markdown]
# # Анализ галлюцинаций нейро-сотрудника
#
# ## Потенциальные галлюцинации
#
# При использовании LLM для анализа интерфейса возможны следующие типы галлюцинаций:
#
# 1. неверное определение назначения элемента интерфейса
# 2. предположение несуществующей бизнес-логики поля
# 3. вывод о состояниях интерфейса, отсутствующих в DOM
# 4. генерация тестов, не связанных с найденными элементами
# 5. завышенная оценка security-рисков
#
# Такие ошибки могут возникать из-за недостатка контекста или попытки модели обобщить поведение интерфейса.
#
# ---
#
# ## Симптомы галлюцинаций
#
# Галлюцинации можно распознать по следующим признакам:
#
# - тесты не связаны с DOM-структурой страницы
# - тесты не подтверждаются базой знаний QA
# - предложения носят слишком общий характер
# - модель предполагает функциональность, отсутствующую в интерфейсе
#
# ---
#
# ## Методы снижения галлюцинаций
#
# В проекте используются следующие техники:
#
# - rule-based генерация части тестов
# - использование базы знаний (RAG)
# - структурированный JSON-формат ответов
# - разделение AI-генерации и rule-based логики
# - deduplication тестов
# - ограничение контекста только релевантными элементами DOM
#
# Такой подход позволяет снизить вероятность генерации некорректных рекомендаций.
#
# ---
#
# ## Остаточные риски
#
# Полностью исключить галлюцинации невозможно.
#
# Поэтому в системе используется следующий принцип:
#
# AI-выводы рассматриваются как **гипотезы тестирования**, которые должны проверяться QA-инженером.

# %% [markdown]
# # **Безопасность нейро-сотрудника**
# # Ограничения системы
#
# Нейро-сотрудник предназначен исключительно для задач анализа интерфейса и генерации тестов.
#
# Он:
#
# - отвечает только на вопросы, связанные с тестированием
#
# - не выполняет произвольный код
#
# - не интерпретирует пользовательский ввод как команды
#
# # Защита от prompt injection
#
# Для защиты от манипуляции запросами используются следующие правила:
#
# - пользовательский ввод не рассматривается как системные инструкции
#
# - системный промпт имеет более высокий приоритет
#
# - ответы проверяются на ожидаемую структуру
#
# # Безопасная генерация
#
# Если контекст недостаточен для уверенного анализа:
#
# - нейро-сотрудник сообщает о недостатке данных
#
# - избегает категоричных выводов
#
# - не делает предположений о функциональности, отсутствующей в DOM

# %% [markdown]
# # Гибридное использование LLM
#
# В проекте используется гибридный подход с применением двух типов языковых моделей.
#
# Это позволяет сочетать экспериментальную демонстрацию локальной LLM с более стабильным анализом через внешнюю модель.
#
# ---
#
# ## 1. Локальная русскоязычная instruct-модель
#
# Локальная модель используется для демонстрации применения русскоязычной LLM в архитектуре нейро-сотрудника.
#
# Она применяется для:
#
# - демонстрации генерации тестов
# - эксперимента с reasoning на русском языке
# - иллюстрации возможностей локальных моделей
#
# ---
#
# ## 2. VSEGPT API
#
# VSEGPT используется для выполнения более сложных аналитических задач.
#
# Эта модель применяется в блоках, где требуется:
#
# - анализ большого контекста
# - более стабильное reasoning
# - генерация более точных рекомендаций
#
# ---
#
# ## Роль гибридной архитектуры
#
# Использование двух типов моделей позволяет системе:
#
# - демонстрировать использование локальных LLM
# - обеспечивать более стабильный AI-анализ
# - комбинировать экспериментальные и практические подходы

# %%
# ==========================================================
# Ввод VSEGPT API key
# ==========================================================
# Ключ не хранится в коде и вводится вручную.
# Это безопаснее и позволяет публиковать Colab в GitHub.
# ==========================================================

from getpass import getpass

VSEGPT_API_KEY = getpass("Введите VSEGPT API key: ")

print("VSEGPT API key получен")
# Out:
# Введите VSEGPT API key: ··········
# VSEGPT API key получен

# %%
# ==========================================================
# Helper-функция для вызова VSEGPT API
# ==========================================================
# Эта функция будет использоваться в тех блоках,
# где локальная модель слишком медленная или нестабильная.
# ==========================================================

import requests
import json

def call_vsegpt_api(system_prompt: str, user_prompt: str, model: str = "openai/gpt-4o-mini"):
    """
    Выполняет запрос к VSEGPT API.

    Аргументы:
        system_prompt (str): системный промпт
        user_prompt (str): пользовательский промпт
        model (str): имя модели

    Возвращает:
        str: текст ответа модели
    """
    url = "https://api.vsegpt.ru/v1/chat/completions"

    headers = {
        "Authorization": f"Bearer {VSEGPT_API_KEY}",
        "Content-Type": "application/json"
    }

    payload = {
        "model": model,
        "messages": [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        "temperature": 0.3
    }

    response = requests.post(url, headers=headers, json=payload, timeout=120)
    response.raise_for_status()

    data = response.json()
    return data["choices"][0]["message"]["content"]

# %% [markdown]
# # Генерация структурированных тест-кейсов
#
# После получения рекомендаций от LLM следующим шагом является преобразование ответа модели в более структурированный формат.
#
# Это необходимо для:
#
# - хранения тестовых сценариев
# - последующего анализа результатов
# - возможной интеграции с системами тестирования
#
# ---
#
# ## Нормализация ответа LLM
#
# Ответ языковой модели обычно представляет собой текстовый список рекомендаций.
# Для дальнейшего использования система выполняет **нормализацию ответа**, преобразуя его в структурированный формат.
#
# В проекте используется простая схема преобразования, при которой список рекомендаций превращается в **JSON-структуру тест-кейсов**.
#
# ---
#
# ## Зачем используется JSON
#
# Использование структурированного формата позволяет:
#
# - сохранять тест-кейсы как артефакт run
# - выполнять дальнейший анализ результатов
# - устранять дублирующиеся тесты
# - использовать данные в последующих этапах анализа
#
# Таким образом JSON-формат делает результаты генерации пригодными для дальнейшей автоматизированной обработки.

# %%
# ==========================================================
# Подготовка ответа модели для дальнейшего анализа
# ==========================================================

analysis_answer = demo_answer

print("Ответ модели передан в блок генерации тест-кейсов")
# Out:
# Ответ модели передан в блок генерации тест-кейсов

# %%
# ==========================================================
# Преобразование ответа модели в тест-кейсы
# ==========================================================
# В этом блоке:
# 1. Берём текст ответа модели
# 2. Разбиваем его на отдельные пункты
# 3. Формируем структуру test cases
# ==========================================================

import re

test_cases = []

# Разбиваем текст по строкам
lines = analysis_answer.split("\n")

for line in lines:

    line = line.strip()

    # Убираем нумерацию
    line = re.sub(r"^\d+[\).\s]+", "", line)

    if len(line) < 3:
        continue

    test_case = {
        "test_name": line,
        "object_locator": selected_object.get("locator"),
        "object_type": selected_object.get("object_type"),
        "priority": "medium",
        "source": "LLM"
    }

    test_cases.append(test_case)

print("Сгенерированные тест-кейсы:\n")

for tc in test_cases:
    print(tc["test_name"])
# Out:
# Сгенерированные тест-кейсы:
#
# Проверка наличия поля ввода пароля.
# Проверка правильности форматирования поля ввода (например, наличие идентификатора).
# Проверка доступности поля ввода при наличии ошибок.
# Проверка отображения сообщения об ошибке при некорректном вводе.
# Проверка возможности повторного ввода пароля.

# %%
# ==========================================================
# Просмотр тест-кейсов в JSON формате
# ==========================================================

import json

print(json.dumps(test_cases, ensure_ascii=False, indent=2))
# Out:
# [
#   {
#     "test_name": "Проверка наличия поля ввода пароля.",
#     "object_locator": "#pass",
#     "object_type": "input",
#     "priority": "medium",
#     "source": "LLM"
#   },
#   {
#     "test_name": "Проверка правильности форматирования поля ввода (например, наличие идентификатора).",
#     "object_locator": "#pass",
#     "object_type": "input",
#     "priority": "medium",
#     "source": "LLM"
#   },
#   {
#     "test_name": "Проверка доступности поля ввода при наличии ошибок.",
#     "object_locator": "#pass",
#     "object_type": "input",
#     "priority": "medium",
#     "source": "LLM"
#   },
#   {
#     "test_name": "Проверка отображения сообщения об ошибке при некорректном вводе.",
#     "object_locator": "#pass",
#     "object_type": "input",
#     "priority": "medium",
#     "source": "LLM"
#   },
#   {
#     "test_name": "Проверка возможности повторного ввода пароля.",
#     "object_locator": "#pass",
#     "object_type": "input",
#     "priority": "medium",
# ...

# %%
# ==========================================================
# Сохранение тест-кейсов
# ==========================================================

test_cases_path = os.path.join(
    artifacts_dir,
    "generated_test_cases.json"
)

with open(test_cases_path, "w", encoding="utf-8") as f:
    json.dump(test_cases, f, ensure_ascii=False, indent=2)

print("Тест-кейсы сохранены:")
print(test_cases_path)
# Out:
# Тест-кейсы сохранены:
# /content/drive/MyDrive/AI_Release_Guardian_MVP/Sites/trainer_sedtest-tools_ru/runs/run_009/generated_test_cases.json

# %% [markdown]
# # AI-анализ рисков страницы
#
# На предыдущих этапах система:
#
# - получила HTML страницы
# - выполнила DOM-анализ
# - декомпозировала интерфейс на testable objects
# - сгенерировала тестовые проверки для выбранного UI-элемента
#
# Следующий шаг — анализ страницы **на более высоком уровне абстракции**.
#
# На этом этапе нейро-сотрудник выступает уже не только как помощник по тестированию отдельных элементов, но и как **Release Guardian**, который оценивает состояние интерфейса в целом.
#
# Система анализирует:
#
# - потенциально уязвимые зоны интерфейса
# - риски регрессии
# - UX-проблемы
# - области, требующие повышенного внимания при тестировании
#
# ---
#
# ## Почему нужен анализ на уровне страницы
#
# Анализ отдельных элементов полезен, но не всегда отражает общую картину интерфейса.
#
# Поэтому системе требуется дополнительный уровень reasoning, где учитываются:
#
# - состав интерфейса
# - структура страницы
# - наличие форм, кнопок и полей ввода
# - потенциальные критические пользовательские сценарии
#
# Таким образом формируется **page-level анализ интерфейса**, который дополняет поэлементный анализ UI.

# %%
# ==========================================================
# Подготовка summary страницы для AI-анализа рисков
# ==========================================================
# Здесь мы собираем краткое описание страницы:
# - URL
# - количество объектов
# - распределение по типам
# - несколько примеров элементов
# ==========================================================

from collections import Counter
import json
import os

# Восстанавливаем имя run, если переменная пропала
if "current_run_name" not in globals():
    current_run_name = os.path.basename(run_dir)

# Считаем количество объектов по типам
page_object_counter = Counter(obj["object_type"] for obj in testable_objects)

# Берём несколько примеров объектов
object_examples = []
for obj in testable_objects[:10]:
    object_examples.append({
        "object_type": obj.get("object_type", ""),
        "display_name": obj.get("display_name", ""),
        "locator": obj.get("locator", ""),
        "text": obj.get("text", "")[:100]
    })

page_summary = {
    "target_url": TARGET_URL,
    "site_name": site_name,
    "current_run_name": current_run_name,
    "total_objects": len(testable_objects),
    "object_type_distribution": dict(page_object_counter),
    "examples": object_examples
}

print("Сводка страницы для анализа рисков:\n")
print(json.dumps(page_summary, ensure_ascii=False, indent=2))
# Out:
# Сводка страницы для анализа рисков:
#
# {
#   "target_url": "https://trainer.sedtest-tools.ru/checkpass/",
#   "site_name": "trainer_sedtest-tools_ru",
#   "current_run_name": "run_009",
#   "total_objects": 6,
#   "object_type_distribution": {
#     "input": 1,
#     "button": 4,
#     "image": 1
#   },
#   "examples": [
#     {
#       "object_type": "input",
#       "display_name": "pass",
#       "locator": "#pass",
#       "text": ""
#     },
#     {
#       "object_type": "button",
#       "display_name": "showCasesBtn",
#       "locator": "#showCasesBtn",
#       "text": "Показать все тест-кейсы"
#     },
#     {
#       "object_type": "button",
#       "display_name": "hideCasesBtn",
#       "locator": "#hideCasesBtn",
#       "text": "Скрыть тест-кейсы"
#     },
#     {
#       "object_type": "button",
#       "display_name": "checkBtn",
#       "locator": "#checkBtn",
#       "text": "Проверить"
#     },
#     {
#       "object_type": "button",
# ...

# %% [markdown]
#  **Helper для локальной русскоязычной LLM**
#
# Для повышения качества генерации локальная модель вызывается через единый helper, использующий chat template и строгую структуру ответа.

# %%
# ==========================================================
# Helper для локальной русскоязычной LLM
# ==========================================================

import torch

def call_local_ru_llm(system_prompt: str, user_prompt: str, max_new_tokens: int = 250):
    """
    Унифицированный вызов локальной русскоязычной LLM.
    Использует chat template и возвращает только новый сгенерированный текст.
    """

    safe_system_prompt = safety_filter(system_prompt)
    safe_user_prompt = safety_filter(user_prompt)

    messages = [
        {
            "role": "system",
            "content": safe_system_prompt
        },
        {
            "role": "user",
            "content": safe_user_prompt
        }
    ]

    text = ru_tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
    )

    inputs = ru_tokenizer(text, return_tensors="pt")

    if torch.cuda.is_available():
        inputs = {k: v.to("cuda") for k, v in inputs.items()}
    else:
        inputs = {k: v.to(ru_model.device) for k, v in inputs.items()}

    outputs = ru_model.generate(
        **inputs,
        max_new_tokens=max_new_tokens,
        do_sample=False,
        pad_token_id=ru_tokenizer.eos_token_id,
        eos_token_id=ru_tokenizer.eos_token_id
    )

    generated_tokens = outputs[0][inputs["input_ids"].shape[1]:]
    answer = ru_tokenizer.decode(generated_tokens, skip_special_tokens=True).strip()

    return answer

# %%
# ==========================================================
# AI-анализ рисков страницы через локальную русскоязычную LLM
# ==========================================================
# Для локальной модели используем короткий и строго структурированный prompt.
# ==========================================================

page_risk_prompt_llm = f"""
Сводка страницы:
{json.dumps(page_summary, ensure_ascii=False, indent=2)}

Сделай анализ рисков страницы.

Ответь строго по шаблону:

1. Основные риски:
2. Возможные зоны регрессии:
3. Что проверить в первую очередь:
4. Возможные UX-проблемы:
5. Достаточность данных:

Пиши кратко и по существу.
Не повторяй инструкцию.
Не пиши фразы вроде "делай выводы на основе данных".
"""

page_risk_analysis_llm = call_local_ru_llm(
    system_prompt=(
        "Ты опытный QA Lead. "
        "Анализируй интерфейс страницы по предоставленной summary. "
        "Отвечай строго по шаблону, кратко, на русском языке."
    ),
    user_prompt=page_risk_prompt_llm,
    max_new_tokens=420
)

print("Результат AI-анализа рисков страницы:\n")
print(page_risk_analysis_llm)
# Out:
# Результат AI-анализа рисков страницы:
#
# 1. Основные риски:
#    - Неправильная работа кнопок (например, "Show Cases" или "Hide Cases") может привести к непредвиденному отображению контента.
#    - Риск ошибки при проверке (например, неверное указание текста для кнопки "Check").
#
# 2. Возможные зоны регрессии:
#    - Кнопки с текстом "Show Cases" и "Hide Cases", которые могут быть связаны с показом/скрытием тест-кейсов.
#    - Кнопка "Check", которая должна проверять результаты тестирования.
#
# 3. Что проверить в первую очередь:
#    - Проверить работу всех элементов управления (ввода, кнопок, изображений).
#    - Убедиться, что кнопки "Check" и "Show Cases" работают корректно.
#    - Проверить наличие и правильность расположения кнопок "Show Cases" и "Hide Cases".
#
# 4. Возможные UX-проблемы:
#    - Возможно, пользователь не сможет найти кнопку "Check", если она находится под другим элементом.
# ...

# %% [markdown]
# # **Наблюдение по качеству локальной LLM**
#
# В ходе эксперимента была протестирована локальная русскоязычная instruct-модель для задач анализа интерфейса и генерации QA-выводов.
#
# Первоначальная версия промпта приводила к слишком общим и малоинформативным ответам. Модель нередко повторяла инструкции или формировала шаблонные фразы без содержательного анализа.
#
# После доработки промпта и перехода на chat template качество генерации заметно улучшилось. Модель начала выдавать структурированный QA-анализ страницы, включая:
#
# - выявление потенциальных рисков интерфейса
#
# - указание возможных зон регрессии
#
# - формирование приоритетных направлений тестирования
#
# - базовые UX-наблюдения
#
# Полученный результат показывает, что:
#
# - локальная модель технически способна выполнять reasoning-задачи на русском языке
#
# - однако качество анализа остаётся менее стабильным по сравнению с внешними LLM-сервисами
#
# - компактные локальные модели могут давать более общие выводы при сложных аналитических задачах
#
# **В рамках данного проекта локальная LLM используется как экспериментальный слой анализа, тогда как основной reasoning выполняется через VSEGPT.**

# %%
# ==========================================================
# Формирование prompt для анализа рисков страницы
# ==========================================================

page_risk_prompt = f"""
На основе структуры страницы:

{page_summary}

Выполни QA-анализ интерфейса и определи:

1. Основные риски:
2. Возможные зоны регрессии:
3. Что проверить в первую очередь:
4. Возможные UX-проблемы:
5. Достаточность данных:

Отвечай кратко и структурировано.
"""

# %%
# ==========================================================
# AI-анализ рисков страницы через VSEGPT
# ==========================================================

page_risk_analysis_vsegpt = call_vsegpt_api(
    system_prompt=(
        "Ты опытный QA Lead и Release Guardian. "
        "Анализируй интерфейс страницы по summary из DOM-анализа. "
        "Не выдумывай элементы, которых нет во входных данных."
    ),
    user_prompt=page_risk_prompt,
    model="openai/gpt-4o-mini"
)

print("Анализ рисков (VSEGPT):\n")
print(page_risk_analysis_vsegpt)
# Out:
# Анализ рисков (VSEGPT):
#
# ### 1. Основные риски:
# - **Неправильная работа кнопок**: Возможные проблемы с функциональностью кнопок (например, не срабатывают события).
# - **Проблемы с вводом данных**: Поле для ввода пароля может не обрабатывать данные корректно (например, не отображает введенные символы).
# - **Отсутствие изображений**: Если изображение не загружается, это может повлиять на восприятие интерфейса.
#
# ### 2. Возможные зоны регрессии:
# - **Кнопки**: Все кнопки (показать/скрыть тест-кейсы, проверить, показать баги) должны быть протестированы на функциональность и взаимодействие.
# - **Поле ввода**: Проверка на корректность ввода и обработку данных.
# - **Изображение**: Проверка загрузки и отображения изображения.
#
# ### 3. Что проверить в первую очередь:
# - **Функциональность кнопки "Проверить"**: Убедиться, что она выполняет свою основную задачу.
# - **Поле ввода пароля**: Проверить, что вводимые данные обрабатываются корректно.
# ...

# %% [markdown]
# # Сохранение результатов анализа рисков
#
# Для сравнения качества генерации в проекте сохраняются два варианта анализа рисков страницы:
#
# - результат локальной русскоязычной LLM
# - результат внешней модели через VSEGPT API
#
# ---
#
# ## Цель сравнения моделей
#
# Сохранение двух вариантов анализа позволяет:
#
# - сравнить стабильность генерации
# - оценить содержательность ответов
# - проанализировать различия в reasoning моделей
#
# Таким образом система фиксирует результаты работы разных моделей для одной и той же задачи.
#
# ---
#
# ## Run-артефакты анализа
#
# Результаты анализа сохраняются как артефакты текущего **run**.
#
# Это позволяет:
#
# - воспроизводить результаты анализа
# - сравнивать выводы моделей
# - использовать данные для последующего анализа интерфейса

# %%
# ==========================================================
# Сохранение результатов анализа рисков:
# 1. локальная LLM
# 2. VSEGPT API
# ==========================================================
# В этом блоке:
# - проверяем наличие результатов
# - сохраняем каждый результат в отдельный JSON
# - сохраняем общий сравнительный JSON
# ==========================================================

import os
import json

# ----------------------------------------------------------
# Проверка имени текущего run
# ----------------------------------------------------------
# Если current_run_name исчез после перезапуска runtime,
# восстанавливаем его по имени папки run_dir.
# ----------------------------------------------------------
if "current_run_name" not in globals():
    current_run_name = os.path.basename(run_dir)

# ----------------------------------------------------------
# Безопасная подстановка результатов
# ----------------------------------------------------------
# Если какая-то из моделей не запускалась, сохраняем
# понятную заглушку вместо ошибки.
# ----------------------------------------------------------
llm_result = globals().get(
    "page_risk_analysis_llm",
    "Результат локальной LLM отсутствует"
)

vsegpt_result = globals().get(
    "page_risk_analysis_vsegpt",
    "Результат VSEGPT отсутствует"
)

# ----------------------------------------------------------
# Формируем отдельный JSON для локальной LLM
# ----------------------------------------------------------
site_risk_analysis_llm = {
    "target_url": TARGET_URL,
    "site_name": site_name,
    "current_run_name": current_run_name,
    "analysis_source": "local_llm",
    "page_summary": page_summary,
    "page_risk_prompt": page_risk_prompt,
    "page_risk_analysis": llm_result
}

site_risk_analysis_llm_path = os.path.join(
    artifacts_dir,
    "site_risk_analysis_llm.json"
)

with open(site_risk_analysis_llm_path, "w", encoding="utf-8") as f:
    json.dump(site_risk_analysis_llm, f, ensure_ascii=False, indent=2)

print("Сохранён результат локальной LLM:")
print(site_risk_analysis_llm_path)

# ----------------------------------------------------------
# Формируем отдельный JSON для VSEGPT
# ----------------------------------------------------------
site_risk_analysis_vsegpt = {
    "target_url": TARGET_URL,
    "site_name": site_name,
    "current_run_name": current_run_name,
    "analysis_source": "vsegpt",
    "page_summary": page_summary,
    "page_risk_prompt": page_risk_prompt,
    "page_risk_analysis": vsegpt_result
}

site_risk_analysis_vsegpt_path = os.path.join(
    artifacts_dir,
    "site_risk_analysis_vsegpt.json"
)

with open(site_risk_analysis_vsegpt_path, "w", encoding="utf-8") as f:
    json.dump(site_risk_analysis_vsegpt, f, ensure_ascii=False, indent=2)

print("Сохранён результат VSEGPT:")
print(site_risk_analysis_vsegpt_path)

# ----------------------------------------------------------
# Формируем общий сравнительный JSON
# ----------------------------------------------------------
site_risk_analysis_comparison = {
    "target_url": TARGET_URL,
    "site_name": site_name,
    "current_run_name": current_run_name,
    "page_summary": page_summary,
    "page_risk_prompt": page_risk_prompt,
    "results": {
        "local_llm": llm_result,
        "vsegpt": vsegpt_result
    }
}

site_risk_analysis_comparison_path = os.path.join(
    artifacts_dir,
    "site_risk_analysis_comparison.json"
)

with open(site_risk_analysis_comparison_path, "w", encoding="utf-8") as f:
    json.dump(site_risk_analysis_comparison, f, ensure_ascii=False, indent=2)

print("Сохранён сравнительный файл:")
print(site_risk_analysis_comparison_path)
# Out:
# Сохранён результат локальной LLM:
# /content/drive/MyDrive/AI_Release_Guardian_MVP/Sites/trainer_sedtest-tools_ru/runs/run_009/site_risk_analysis_llm.json
# Сохранён результат VSEGPT:
# /content/drive/MyDrive/AI_Release_Guardian_MVP/Sites/trainer_sedtest-tools_ru/runs/run_009/site_risk_analysis_vsegpt.json
# Сохранён сравнительный файл:
# /content/drive/MyDrive/AI_Release_Guardian_MVP/Sites/trainer_sedtest-tools_ru/runs/run_009/site_risk_analysis_comparison.json

# %%
# ==========================================================
# Быстрая проверка файлов в текущем run
# ==========================================================

print("Файлы в текущем run:\n")

for file_name in sorted(os.listdir(artifacts_dir)):
    print("-", file_name)
# Out:
# Файлы в текущем run:
#
# - generated_test_cases.json
# - generated_test_cases_by_type.json
# - page_screenshot.png
# - representative_objects_by_type.json
# - site_risk_analysis_comparison.json
# - site_risk_analysis_llm.json
# - site_risk_analysis_vsegpt.json
# - testable_objects.json

# %% [markdown]
# # Генерация site-level UI checks
#
# Помимо тестов для отдельных типов элементов, система формирует проверки уровня всей страницы.
#
# Это позволяет анализировать интерфейс как целостную **UI-систему**, а не только как набор отдельных элементов.
#
# Такие проверки дополняют element-level тесты и позволяют выявлять проблемы, связанные со структурой страницы и пользовательскими сценариями.
#
# ---
#
# ## Что покрывают site-level проверки
#
# Site-level проверки позволяют анализировать:
#
# - общую работоспособность страницы
# - формы и пользовательские сценарии
# - навигацию между элементами интерфейса
# - базовую доступность элементов
# - UX consistency
#
# ---
#
# ## Роль в архитектуре анализа
#
# Таким образом система использует **многоуровневый подход к тестированию интерфейса**:
#
# - element-level анализ (отдельные UI-элементы)
# - page-level анализ (структура страницы)
#
# Это позволяет получить более полное представление о состоянии интерфейса.

# %%
# ==========================================================
# Site-level UI checks
# ==========================================================
# Эта ячейка:
# 1. Использует summary страницы
# 2. Генерирует проверки уровня всей страницы
# 3. Не заменяет tests_by_type, а дополняет их
# ==========================================================

import json

# Проверяем, что page_summary уже существует
if "page_summary" not in globals() or not page_summary:
    raise Exception(
        "page_summary не найден. "
        "Сначала выполни блок подготовки summary страницы."
    )

site_ui_prompt = f"""
Ты опытный QA Lead.

Ниже приведена summary страницы:
{json.dumps(page_summary, ensure_ascii=False, indent=2)}

Сгенерируй site-level UI checks для страницы.

Нужны проверки по направлениям:
1. Общая работоспособность страницы
2. Формы и пользовательские сценарии
3. Навигация и интерактивность
4. Accessibility basics
5. UX consistency
6. Ошибки отображения и состояния элементов

Требования:
- ответ на русском языке
- не выдумывай отсутствующие элементы
- опирайся только на summary страницы
"""

site_level_ui_checks = call_vsegpt_api(
    system_prompt=(
        "Ты опытный QA Lead. "
        "Генерируй site-level UI checks по summary интерфейса."
    ),
    user_prompt=site_ui_prompt,
    model="openai/gpt-4o-mini"
)

print("Site-level UI checks:\n")
print(site_level_ui_checks)
# Out:
# Site-level UI checks:
#
# ### Site-Level UI Checks для страницы https://trainer.sedtest-tools.ru/checkpass/
#
# #### 1. Общая работоспособность страницы
# - [ ] Проверить, что страница загружается без ошибок (HTTP 200).
# - [ ] Убедиться, что все элементы интерфейса отображаются корректно (input, кнопки, изображение).
# - [ ] Проверить, что все элементы страницы имеют корректные локаторы, указанные в summary.
#
# #### 2. Формы и пользовательские сценарии
# - [ ] Проверить, что поле ввода пароля (`#pass`) доступно для ввода текста.
# - [ ] Убедиться, что кнопка "Проверить" (`#checkBtn`) активна и доступна для клика.
# - [ ] Проверить, что при нажатии на кнопку "Показать все тест-кейсы" (`#showCasesBtn`) отображаются все тест-кейсы.
# - [ ] Убедиться, что при нажатии на кнопку "Скрыть тест-кейсы" (`#hideCasesBtn`) тест-кейсы скрываются.
# - [ ] Проверить, что кнопка "Показать все баги" (`#showBugsBtn`) активна и отображает все баги при нажатии.
#
# #### 3. Навигация и интерактивность
# ...

# %% [markdown]
# # Visual consistency checks
#
# Помимо функциональных и site-level проверок, система формирует список визуальных UI-проверок.
#
# На этом этапе не выполняется полноценный **pixel-diff анализ**, однако генерируется checklist для **visual regression** и **UI consistency testing**.
#
# Такой подход позволяет выявить потенциальные визуальные проблемы интерфейса после изменений или релизов.
#
# ---
#
# ## Что проверяют visual checks
#
# Система формирует рекомендации для проверки:
#
# - выравнивания элементов
# - обрезания текста
# - перекрытия элементов
# - консистентности кнопок и полей
# - layout и spacing
# - визуальных ошибок после релиза
#
# ---
#
# ## Роль visual checks в системе
#
# Visual проверки дополняют функциональные тесты и позволяют анализировать интерфейс на уровне визуального качества.
#
# В результате система использует **комбинированный подход к анализу интерфейса**:
#
# - функциональные проверки элементов
# - site-level проверки страницы
# - визуальные UI-проверки

# %%
# ==========================================================
# Visual consistency checks
# ==========================================================
# Эта ячейка:
# 1. Использует page_summary
# 2. Генерирует visual / layout / UI consistency checklist
# 3. Не заменяет risk analysis, а дополняет его
#
# ВАЖНО:
# - это не настоящий pixel-diff engine
# - это AI-generated visual QA checklist
# ==========================================================

import json

# Проверяем, что page_summary уже существует
if "page_summary" not in globals() or not page_summary:
    raise Exception(
        "page_summary не найден. "
        "Сначала выполни блок формирования summary страницы."
    )

visual_prompt = f"""
Ты опытный QA инженер по UI и visual regression testing.

Ниже приведена summary страницы:
{json.dumps(page_summary, ensure_ascii=False, indent=2)}

Сформируй список visual / layout / UI consistency checks.

Нужны проверки по направлениям:
1. Выравнивание элементов
2. Обрезание текста
3. Перекрытие элементов
4. Отступы и spacing
5. Консистентность кнопок и полей
6. Видимость элементов
7. Ошибки layout
8. Что проверить визуально после релиза

Требования:
- ответ на русском языке
- не выдумывай отсутствующие элементы
- опирайся только на summary страницы
"""

visual_consistency_checks = call_vsegpt_api(
    system_prompt=(
        "Ты QA-инженер по UI и visual regression testing. "
        "Генерируй visual consistency checklist."
    ),
    user_prompt=visual_prompt,
    model="openai/gpt-4o-mini"
)

print("Visual consistency checks:\n")
print(visual_consistency_checks)
# Out:
# Visual consistency checks:
#
# ### Visual / Layout / UI Consistency Checklist
#
# #### 1. Выравнивание элементов
# - Проверьте, что все элементы (входные поля, кнопки и изображения) выровнены по сетке (grid) или по заданным правилам выравнивания.
# - Убедитесь, что текст в кнопках и полях ввода выровнен по центру или по левому краю в зависимости от дизайна.
#
# #### 2. Обрезание текста
# - Проверьте, что текст на кнопках ("Показать все тест-кейсы", "Скрыть тест-кейсы", "Проверить", "Показать все баги") не обрезается и полностью виден.
# - Убедитесь, что текст в поле ввода (например, для пароля) не обрезается и отображается корректно.
#
# #### 3. Перекрытие элементов
# - Проверьте, что кнопки не перекрывают друг друга и находятся на достаточном расстоянии друг от друга.
# - Убедитесь, что изображение не перекрывает другие элементы интерфейса.
#
# #### 4. Отступы и spacing
# ...

# %% [markdown]
# # Сохранение дополнительных артефактов анализа
#
# Результаты генерации по типам объектов, site-level UI checks и visual consistency checks сохраняются в текущую **run-папку** как отдельные артефакты анализа.
#
# ---
#
# ## Какие данные сохраняются
#
# Система сохраняет:
#
# - тестовые сценарии для типов объектов
# - site-level UI checks
# - visual consistency checks
#
# Эти данные становятся частью итоговых артефактов анализа интерфейса.
#
# ---
#
# ## Зачем сохраняются дополнительные артефакты
#
# Сохранение результатов позволяет:
#
# - использовать их в истории запусков
# - сравнивать качество анализа между версиями
# - расширять итоговый **run_summary**
#
# Таким образом каждый запуск системы формирует полный набор данных анализа интерфейса, который может использоваться для последующего сравнения и оценки изменений.

# %%
# ==========================================================
# Сохранение новых артефактов анализа
# ==========================================================
# Эта ячейка сохраняет:
# 1. representative_objects_by_type.json
# 2. generated_test_cases_by_type.json
# 3. site_level_ui_checks.json
# 4. visual_consistency_checks.json
#
# ВАЖНО:
# - старые артефакты не перезаписываются
# - текущий pipeline не ломается
# ==========================================================

import os
import json

# ----------------------------------------------------------
# Проверка обязательных переменных
# ----------------------------------------------------------
required_objects = {
    "representative_objects": "representative_objects_by_type.json",
    "tests_by_type": "generated_test_cases_by_type.json",
    "site_level_ui_checks": "site_level_ui_checks.json",
    "visual_consistency_checks": "visual_consistency_checks.json"
}

for var_name in required_objects:
    if var_name not in globals():
        raise Exception(
            f"Переменная {var_name} не найдена. "
            f"Сначала выполни соответствующий блок."
        )

# ----------------------------------------------------------
# 1. Representative objects
# ----------------------------------------------------------
representative_objects_path = os.path.join(
    artifacts_dir,
    "representative_objects_by_type.json"
)

with open(representative_objects_path, "w", encoding="utf-8") as f:
    json.dump(representative_objects, f, ensure_ascii=False, indent=2)

print("Сохранён файл:")
print(representative_objects_path)

# ----------------------------------------------------------
# 2. Tests by type
# ----------------------------------------------------------
tests_by_type_path = os.path.join(
    artifacts_dir,
    "generated_test_cases_by_type.json"
)

with open(tests_by_type_path, "w", encoding="utf-8") as f:
    json.dump(tests_by_type, f, ensure_ascii=False, indent=2)

print("Сохранён файл:")
print(tests_by_type_path)

# ----------------------------------------------------------
# 3. Site-level UI checks
# ----------------------------------------------------------
site_level_checks_path = os.path.join(
    artifacts_dir,
    "site_level_ui_checks.json"
)

with open(site_level_checks_path, "w", encoding="utf-8") as f:
    json.dump({
        "target_url": TARGET_URL,
        "site_name": site_name,
        "run_name": current_run_name,
        "site_level_ui_checks": site_level_ui_checks
    }, f, ensure_ascii=False, indent=2)

print("Сохранён файл:")
print(site_level_checks_path)

# ----------------------------------------------------------
# 4. Visual consistency checks
# ----------------------------------------------------------
visual_checks_path = os.path.join(
    artifacts_dir,
    "visual_consistency_checks.json"
)

with open(visual_checks_path, "w", encoding="utf-8") as f:
    json.dump({
        "target_url": TARGET_URL,
        "site_name": site_name,
        "run_name": current_run_name,
        "visual_consistency_checks": visual_consistency_checks
    }, f, ensure_ascii=False, indent=2)

print("Сохранён файл:")
print(visual_checks_path)

print("\nНовые артефакты успешно добавлены в текущий run.")
# Out:
# Сохранён файл:
# /content/drive/MyDrive/AI_Release_Guardian_MVP/Sites/trainer_sedtest-tools_ru/runs/run_009/representative_objects_by_type.json
# Сохранён файл:
# /content/drive/MyDrive/AI_Release_Guardian_MVP/Sites/trainer_sedtest-tools_ru/runs/run_009/generated_test_cases_by_type.json
# Сохранён файл:
# /content/drive/MyDrive/AI_Release_Guardian_MVP/Sites/trainer_sedtest-tools_ru/runs/run_009/site_level_ui_checks.json
# Сохранён файл:
# /content/drive/MyDrive/AI_Release_Guardian_MVP/Sites/trainer_sedtest-tools_ru/runs/run_009/visual_consistency_checks.json
#
# Новые артефакты успешно добавлены в текущий run.

# %% [markdown]
# # Обновление финальной сводки запуска
#
# После добавления новых слоёв анализа итоговая сводка запуска обновляется.
#
# Теперь **run_summary** включает:
#
# - артефакты по representative elements
# - тесты по типам объектов
# - site-level UI checks
# - visual consistency checks
#
# ---
#
# ## Роль run_summary
#
# run_summary выступает в роли агрегированного отчёта анализа интерфейса.
#
# Он объединяет результаты всех этапов пайплайна и предоставляет краткую сводку текущего состояния страницы.
#
# ---
#
# ## Snapshot анализа интерфейса
#
# Благодаря этому каждая run-папка представляет собой **snapshot анализа интерфейса**, содержащий:
#
# - структуру страницы
# - найденные UI-элементы
# - рекомендации по тестированию
# - результаты AI-анализа
#
# Это позволяет сравнивать результаты между запусками и отслеживать изменения интерфейса со временем.

# %%
# ==========================================================
# Обновление финальной сводки run
# ==========================================================
# Эта ячейка:
# 1. Перечитывает список файлов в artifacts_dir
# 2. Пересобирает run_summary
# 3. Сохраняет обновлённый run_summary.json
# 4. Красиво завершает pipeline
# ==========================================================

import os
import json

# Если current_run_name исчез после перезапуска runtime
if "current_run_name" not in globals():
    current_run_name = os.path.basename(run_dir)

# Список всех артефактов текущего run
current_artifacts = sorted(os.listdir(artifacts_dir))

updated_run_summary = {
    "target_url": TARGET_URL,
    "site_name": site_name,
    "run_name": current_run_name,
    "total_testable_objects": len(testable_objects),
    "total_object_types": len(representative_objects) if "representative_objects" in globals() else None,
    "artifacts": current_artifacts
}

updated_run_summary_path = os.path.join(
    artifacts_dir,
    "run_summary.json"
)

with open(updated_run_summary_path, "w", encoding="utf-8") as f:
    json.dump(updated_run_summary, f, ensure_ascii=False, indent=2)

print("Обновлённый run_summary сохранён:")
print(updated_run_summary_path)

print("\nАктуальные артефакты текущего run:\n")
for file_name in current_artifacts:
    print("-", file_name)

print("\nAI Release Guardian analysis completed.")
print("Site:", site_name)
print("Run:", current_run_name)
print("Artifacts saved to:", artifacts_dir)
# Out:
# Обновлённый run_summary сохранён:
# /content/drive/MyDrive/AI_Release_Guardian_MVP/Sites/trainer_sedtest-tools_ru/runs/run_009/run_summary.json
#
# Актуальные артефакты текущего run:
#
# - generated_test_cases.json
# - generated_test_cases_by_type.json
# - page_screenshot.png
# - representative_objects_by_type.json
# - site_level_ui_checks.json
# - site_risk_analysis_comparison.json
# - site_risk_analysis_llm.json
# - site_risk_analysis_vsegpt.json
# - testable_objects.json
# - visual_consistency_checks.json
#
# AI Release Guardian analysis completed.
# Site: trainer_sedtest-tools_ru
# Run: run_009
# Artifacts saved to: /content/drive/MyDrive/AI_Release_Guardian_MVP/Sites/trainer_sedtest-tools_ru/runs/run_009

# %% [markdown]
# # Diff-анализ интерфейса между запусками
#
# Одной из задач **AI Release Guardian** является обнаружение изменений интерфейса между версиями сайта.
#
# Каждый запуск анализа сохраняет результаты DOM-декомпозиции в виде файла **testable_objects.json**.
#
# Сравнивая такие файлы между разными run, система может определить:
#
# - какие элементы появились
# - какие элементы исчезли
# - какие элементы изменились
#
# Это позволяет выявлять потенциальные зоны регрессии и планировать дополнительное тестирование.
#
# ---
#
# ## Роль diff-анализа
#
# Diff-анализ позволяет перейти от анализа отдельной страницы к **анализу изменений интерфейса между версиями**.
#
# Таким образом система может обнаруживать изменения UI, которые могут повлиять на пользовательские сценарии.
#
# ---
#
# ## Release-level анализ
#
# Diff между run используется как основа для **release-level reasoning**, где система оценивает:
#
# - потенциальные регрессии
# - новые риски интерфейса
# - области, требующие дополнительного тестирования
#
# Это делает AI Release Guardian инструментом поддержки QA-процесса при выпуске новых версий интерфейса.

# %%
# ==========================================================
# Диагностика путей run
# ==========================================================

import os

print("site_name:", site_name)
print("runs_dir:", runs_dir)
print("run_dir:", run_dir)
print("current_run_name:", current_run_name)

print("\nПапки в runs_dir:")
if os.path.exists(runs_dir):
    for item in sorted(os.listdir(runs_dir)):
        print("-", item)
else:
    print("runs_dir не существует")
# Out:
# site_name: trainer_sedtest-tools_ru
# runs_dir: /content/drive/MyDrive/AI_Release_Guardian_MVP/Sites/trainer_sedtest-tools_ru/runs
# run_dir: /content/drive/MyDrive/AI_Release_Guardian_MVP/Sites/trainer_sedtest-tools_ru/runs/run_009
# current_run_name: run_009
#
# Папки в runs_dir:
# - run_001
# - run_002
# - run_003
# - run_004
# - run_005
# - run_006
# - run_007
# - run_008
# - run_009

# %%
# ==========================================================
# Выбор предыдущего и текущего run для diff-анализа
# ==========================================================

import os
import re

# Гарантируем, что runs_dir соответствует run_dir
runs_dir = os.path.dirname(run_dir)

all_runs = sorted([
    d for d in os.listdir(runs_dir)
    if re.match(r"run_\d{3}$", d)
])

print("Найденные run:")
print(all_runs)

if current_run_name not in all_runs:
    raise Exception(
        f"Текущий run {current_run_name} не найден в runs_dir: {runs_dir}"
    )

current_index = all_runs.index(current_run_name)

if current_index == 0:
    raise Exception("Для diff-анализа нужен хотя бы один предыдущий run.")

run_old = all_runs[current_index - 1]
run_new = current_run_name

print("Сравниваем:")
print("OLD:", run_old)
print("NEW:", run_new)
# Out:
# Найденные run:
# ['run_001', 'run_002', 'run_003', 'run_004', 'run_005', 'run_006', 'run_007', 'run_008', 'run_009']
# Сравниваем:
# OLD: run_008
# NEW: run_009

# %%
# ==========================================================
# Загрузка testable_objects двух запусков
# ==========================================================

import json
import os

# runs_dir уже создан в блоке RUN ARCHITECTURE
# и указывает на папку runs конкретного сайта

path_old = os.path.join(runs_dir, run_old, "testable_objects.json")
path_new = os.path.join(runs_dir, run_new, "testable_objects.json")

print("OLD path:", path_old)
print("NEW path:", path_new)

# Загружаем данные
with open(path_old, "r", encoding="utf-8") as f:
    objects_old = json.load(f)

with open(path_new, "r", encoding="utf-8") as f:
    objects_new = json.load(f)

print("OLD objects:", len(objects_old))
print("NEW objects:", len(objects_new))
# Out:
# OLD path: /content/drive/MyDrive/AI_Release_Guardian_MVP/Sites/trainer_sedtest-tools_ru/runs/run_008/testable_objects.json
# NEW path: /content/drive/MyDrive/AI_Release_Guardian_MVP/Sites/trainer_sedtest-tools_ru/runs/run_009/testable_objects.json
# OLD objects: 6
# NEW objects: 6

# %%
# ==========================================================
# Индексирование элементов по locator
# ==========================================================

old_index = {obj["locator"]: obj for obj in objects_old}
new_index = {obj["locator"]: obj for obj in objects_new}

old_locators = set(old_index.keys())
new_locators = set(new_index.keys())

# %%
# ==========================================================
# Diff-анализ
# ==========================================================

added_elements = new_locators - old_locators
removed_elements = old_locators - new_locators
common_elements = old_locators & new_locators

changed_elements = []

for locator in common_elements:

    old_obj = old_index[locator]
    new_obj = new_index[locator]

    if old_obj != new_obj:
        changed_elements.append(locator)

print("Добавленные элементы:", len(added_elements))
print("Удалённые элементы:", len(removed_elements))
print("Изменённые элементы:", len(changed_elements))
# Out:
# Добавленные элементы: 0
# Удалённые элементы: 0
# Изменённые элементы: 0

# %%
print("\nДобавленные элементы:")
for loc in list(added_elements)[:10]:
    print(loc)

print("\nУдалённые элементы:")
for loc in list(removed_elements)[:10]:
    print(loc)

print("\nИзменённые элементы:")
for loc in changed_elements[:10]:
    print(loc)
# Out:
# Добавленные элементы:
#
# Удалённые элементы:
#
# Изменённые элементы:

# %%
# ==========================================================
# Формирование diff-отчёта
# ==========================================================

diff_report = {
    "site": site_name,
    "old_run": run_old,
    "new_run": run_new,
    "added_elements": list(added_elements),
    "removed_elements": list(removed_elements),
    "changed_elements": changed_elements
}

print(json.dumps(diff_report, ensure_ascii=False, indent=2))
# Out:
# {
#   "site": "trainer_sedtest-tools_ru",
#   "old_run": "run_008",
#   "new_run": "run_009",
#   "added_elements": [],
#   "removed_elements": [],
#   "changed_elements": []
# }

# %%
# ==========================================================
# Сохранение diff-отчёта
# ==========================================================

diff_path = os.path.join(
    runs_dir,
    run_new,
    "ui_diff_report.json"
)

with open(diff_path, "w", encoding="utf-8") as f:
    json.dump(diff_report, f, ensure_ascii=False, indent=2)

print("Diff-отчёт сохранён:")
print(diff_path)
# Out:
# Diff-отчёт сохранён:
# /content/drive/MyDrive/AI_Release_Guardian_MVP/Sites/trainer_sedtest-tools_ru/runs/run_009/ui_diff_report.json

# %% [markdown]
# # AI-анализ изменений интерфейса между запусками
#
# После сравнения двух запусков система уже знает:
#
# - какие элементы были добавлены
# - какие элементы были удалены
# - какие элементы были изменены
#
# Следующий шаг — интерпретировать эти изменения с точки зрения **QA и release risk**.
#
# Для этого diff-отчёт передаётся в LLM, которая выполняет аналитическую интерпретацию изменений интерфейса.
#
# ---
#
# ## Какие вопросы решает AI-анализ
#
# LLM помогает ответить на следующие вопросы:
#
# - какие изменения являются наиболее рискованными
# - где возможна регрессия интерфейса
# - какие пользовательские сценарии следует проверить в первую очередь
# - какие дополнительные тесты стоит добавить
#
# ---
#
# ## Release-level reasoning
#
# Таким образом система выполняет **release-level анализ интерфейса**, используя diff между запусками.
#
# Это позволяет:
#
# - выявлять потенциальные регрессии
# - определять приоритеты тестирования
# - помогать QA-команде планировать проверку новой версии интерфейса

# %%
# ==========================================================
# Подготовка prompt для AI-анализа diff
# ==========================================================
# Используем уже сформированный diff_report и просим модель
# сделать QA / release-oriented интерпретацию изменений.
# ==========================================================

import json
import os

# На всякий случай убеждаемся, что diff_report существует
if "diff_report" not in globals():
    raise Exception("diff_report не найден. Сначала выполни блок diff-анализа между run.")

ui_diff_prompt = f"""
Ты опытный QA Lead и Release Guardian.

Ниже приведён отчёт об изменениях интерфейса между двумя запусками анализа сайта.

Diff report:
{json.dumps(diff_report, ensure_ascii=False, indent=2)}

Сделай анализ изменений и укажи:

1. Краткое summary изменений
2. Какие изменения потенциально наиболее рискованные
3. Какие зоны возможной регрессии есть
4. Какие тесты нужно выполнить в первую очередь
5. Какие проверки стоит добавить в regression suite

Требования:
- ответ на русском языке
- опирайся только на переданный diff
- не выдумывай несуществующие элементы
- если изменений мало или данных недостаточно, прямо укажи это
"""

print("Prompt для AI-анализа diff подготовлен.")
print(ui_diff_prompt[:4000])
# Out:
# Prompt для AI-анализа diff подготовлен.
#
# Ты опытный QA Lead и Release Guardian.
#
# Ниже приведён отчёт об изменениях интерфейса между двумя запусками анализа сайта.
#
# Diff report:
# {
#   "site": "trainer_sedtest-tools_ru",
#   "old_run": "run_008",
#   "new_run": "run_009",
#   "added_elements": [],
#   "removed_elements": [],
#   "changed_elements": []
# }
#
# Сделай анализ изменений и укажи:
#
# 1. Краткое summary изменений
# 2. Какие изменения потенциально наиболее рискованные
# 3. Какие зоны возможной регрессии есть
# 4. Какие тесты нужно выполнить в первую очередь
# 5. Какие проверки стоит добавить в regression suite
#
# Требования:
# - ответ на русском языке
# - опирайся только на переданный diff
# - не выдумывай несуществующие элементы
# - если изменений мало или данных недостаточно, прямо укажи это

# %%
# ==========================================================
# AI-анализ diff через локальную русскоязычную LLM
# ==========================================================
# Для локальной модели используем короткий и строго структурированный prompt.
# ==========================================================

ui_diff_prompt_llm = f"""
Diff report:
{json.dumps(diff_report, ensure_ascii=False, indent=2)}

Проанализируй изменения интерфейса.

Ответь строго по шаблону:

1. Краткое summary изменений:
2. Самое рискованное изменение:
3. Возможная регрессия:
4. Что проверить в первую очередь:
5. Нужны ли дополнительные тесты:

Пиши кратко и по существу.
Не повторяй инструкцию.
Не пиши фразы вроде "делай выводы на основе данных".
"""

ui_diff_analysis_llm = call_local_ru_llm(
    system_prompt=(
        "Ты опытный QA Lead и Release Guardian. "
        "Анализируй diff интерфейса между двумя запусками. "
        "Отвечай строго по шаблону, кратко, на русском языке."
    ),
    user_prompt=ui_diff_prompt_llm,
    max_new_tokens=420
)

print("AI-анализ diff (локальная LLM):\n")
print(ui_diff_analysis_llm)
# Out:
# AI-анализ diff (локальная LLM):
#
# 1. Изменения: Интерфейс стал более компактным, убраны ненужные элементы управления.
# 2. Рискованное изменение: Удаление кнопки "Загрузить" может привести к путанице среди пользователей, так как она используется для загрузки файлов.
# 3. Возможная регрессия: Может возникнуть трудности с управлением процессами или файлами при использовании удаленной загрузки.
# 4. Первые шаги проверки: Проверить, что все необходимые функциональные возможности остались доступными после удаления кнопки.
# 5. Дополнительные тесты: Необходимо провести тестирование с различными типами загружаемых файлов, чтобы убедиться, что они корректно обрабатываются без кнопки "Загрузить".

# %%
# ==========================================================
# AI-анализ diff через VSEGPT API
# ==========================================================

ui_diff_analysis_vsegpt = call_vsegpt_api(
    system_prompt=(
        "Ты опытный QA Lead и Release Guardian. "
        "Анализируй изменения интерфейса между двумя run. "
        "Не выдумывай элементы, которых нет во входных данных. "
        "Фокусируйся на рисках регрессии и приоритетах тестирования."
    ),
    user_prompt=ui_diff_prompt,
    model="openai/gpt-4o-mini"
)

print("AI-анализ diff (VSEGPT):\n")
print(ui_diff_analysis_vsegpt)
# Out:
# AI-анализ diff (VSEGPT):
#
# 1. **Краткое summary изменений**: В отчёте об изменениях между запусками run_008 и run_009 не зафиксировано добавленных, удалённых или изменённых элементов интерфейса. Это указывает на отсутствие каких-либо изменений в интерфейсе сайта trainer_sedtest-tools_ru.
#
# 2. **Какие изменения потенциально наиболее рискованные**: Поскольку изменений нет, риск регрессии в данном случае минимален. Однако, если в предыдущих запусках были выявлены проблемы, стоит учитывать их влияние на текущую версию.
#
# 3. **Какие зоны возможной регрессии есть**: В условиях отсутствия изменений интерфейса, зоны возможной регрессии также отсутствуют. Тем не менее, стоит обратить внимание на функциональность, которая могла быть затронута в предыдущих версиях, если такие данные имеются.
#
# ...

# %%
# ==========================================================
# Сохранение результатов AI-анализа diff
# ==========================================================

# Если current_run_name исчез после перезапуска runtime
if "current_run_name" not in globals():
    current_run_name = os.path.basename(run_dir)

ui_diff_analysis_llm_result = globals().get(
    "ui_diff_analysis_llm",
    "Результат локальной LLM отсутствует"
)

ui_diff_analysis_vsegpt_result = globals().get(
    "ui_diff_analysis_vsegpt",
    "Результат VSEGPT отсутствует"
)

# Отдельный JSON для локальной LLM
ui_diff_ai_analysis_llm = {
    "site_name": site_name,
    "current_run_name": current_run_name,
    "old_run": diff_report["old_run"],
    "new_run": diff_report["new_run"],
    "analysis_source": "local_llm",
    "diff_report": diff_report,
    "ui_diff_prompt": ui_diff_prompt,
    "ui_diff_analysis": ui_diff_analysis_llm_result
}

ui_diff_ai_analysis_llm_path = os.path.join(
    artifacts_dir,
    "ui_diff_ai_analysis_llm.json"
)

with open(ui_diff_ai_analysis_llm_path, "w", encoding="utf-8") as f:
    json.dump(ui_diff_ai_analysis_llm, f, ensure_ascii=False, indent=2)

print("Сохранён diff-анализ локальной LLM:")
print(ui_diff_ai_analysis_llm_path)

# Отдельный JSON для VSEGPT
ui_diff_ai_analysis_vsegpt = {
    "site_name": site_name,
    "current_run_name": current_run_name,
    "old_run": diff_report["old_run"],
    "new_run": diff_report["new_run"],
    "analysis_source": "vsegpt",
    "diff_report": diff_report,
    "ui_diff_prompt": ui_diff_prompt,
    "ui_diff_analysis": ui_diff_analysis_vsegpt_result
}

ui_diff_ai_analysis_vsegpt_path = os.path.join(
    artifacts_dir,
    "ui_diff_ai_analysis_vsegpt.json"
)

with open(ui_diff_ai_analysis_vsegpt_path, "w", encoding="utf-8") as f:
    json.dump(ui_diff_ai_analysis_vsegpt, f, ensure_ascii=False, indent=2)

print("Сохранён diff-анализ VSEGPT:")
print(ui_diff_ai_analysis_vsegpt_path)

# Сравнительный JSON
ui_diff_ai_analysis_comparison = {
    "site_name": site_name,
    "current_run_name": current_run_name,
    "old_run": diff_report["old_run"],
    "new_run": diff_report["new_run"],
    "diff_report": diff_report,
    "ui_diff_prompt": ui_diff_prompt,
    "results": {
        "local_llm": ui_diff_analysis_llm_result,
        "vsegpt": ui_diff_analysis_vsegpt_result
    }
}

ui_diff_ai_analysis_comparison_path = os.path.join(
    artifacts_dir,
    "ui_diff_ai_analysis_comparison.json"
)

with open(ui_diff_ai_analysis_comparison_path, "w", encoding="utf-8") as f:
    json.dump(ui_diff_ai_analysis_comparison, f, ensure_ascii=False, indent=2)

print("Сохранён сравнительный diff-анализ:")
print(ui_diff_ai_analysis_comparison_path)
# Out:
# Сохранён diff-анализ локальной LLM:
# /content/drive/MyDrive/AI_Release_Guardian_MVP/Sites/trainer_sedtest-tools_ru/runs/run_009/ui_diff_ai_analysis_llm.json
# Сохранён diff-анализ VSEGPT:
# /content/drive/MyDrive/AI_Release_Guardian_MVP/Sites/trainer_sedtest-tools_ru/runs/run_009/ui_diff_ai_analysis_vsegpt.json
# Сохранён сравнительный diff-анализ:
# /content/drive/MyDrive/AI_Release_Guardian_MVP/Sites/trainer_sedtest-tools_ru/runs/run_009/ui_diff_ai_analysis_comparison.json

# %% [markdown]
# # Вывод по AI-анализу diff
#
# На этом этапе система выполнила не только техническое сравнение двух запусков, но и интерпретацию изменений с точки зрения QA и release risk.
#
# Таким образом diff используется не только как инструмент сравнения интерфейсов, но и как источник данных для аналитического вывода.
#
# Это позволяет:
#
# - выявлять потенциально опасные изменения интерфейса
# - определять зоны возможной регрессии
# - приоритизировать тестирование после изменений
#
# В результате AI Release Guardian помогает QA-инженеру быстрее оценить влияние изменений интерфейса и определить наиболее критические области для проверки.

# %% [markdown]
# # Оценка риска релиза
#
# На основе diff интерфейса между двумя запусками система вычисляет простую оценку риска релиза (**risk score**).
#
# Оценка строится на основе изменений структуры интерфейса между версиями страницы.
#
# Risk score зависит от количества:
#
# - добавленных элементов
# - удалённых элементов
# - изменённых элементов
#
# ---
#
# ## Интерпретация risk score
#
# Чем больше изменений обнаружено в интерфейсе, тем выше потенциальный риск регрессии.
#
# Такая метрика позволяет быстро оценить, насколько изменения интерфейса могут повлиять на стабильность системы.
#
# ---
#
# ## Роль оценки риска
#
# Оценка риска используется как дополнительный сигнал для QA-инженера и дополняет AI-анализ изменений интерфейса.
#
# Таким образом система сочетает:
#
# - технический diff интерфейса
# - AI-интерпретацию изменений
# - количественную оценку риска релиза

# %%
# ==========================================================
# Release Risk Score
# ==========================================================

added_count = len(added_elements)
removed_count = len(removed_elements)
changed_count = len(changed_elements)

# Простая модель оценки риска
risk_score = (
    added_count * 1 +
    removed_count * 2 +
    changed_count * 3
)

if risk_score < 5:
    risk_level = "LOW"
elif risk_score < 15:
    risk_level = "MEDIUM"
else:
    risk_level = "HIGH"

release_risk = {
    "old_run": run_old,
    "new_run": run_new,
    "added_elements": added_count,
    "removed_elements": removed_count,
    "changed_elements": changed_count,
    "risk_score": risk_score,
    "risk_level": risk_level
}

print("Release Risk Analysis:\n")
print(release_risk)
# Out:
# Release Risk Analysis:
#
# {'old_run': 'run_008', 'new_run': 'run_009', 'added_elements': 0, 'removed_elements': 0, 'changed_elements': 0, 'risk_score': 0, 'risk_level': 'LOW'}

# %%
risk_path = os.path.join(
    artifacts_dir,
    "release_risk_analysis.json"
)

with open(risk_path, "w", encoding="utf-8") as f:
    json.dump(release_risk, f, ensure_ascii=False, indent=2)

print("Release risk сохранён:")
print(risk_path)
# Out:
# Release risk сохранён:
# /content/drive/MyDrive/AI_Release_Guardian_MVP/Sites/trainer_sedtest-tools_ru/runs/run_009/release_risk_analysis.json

# %% [markdown]
# На основе diff интерфейса между версиями система вычисляет простую метрику **Release Risk Score**, которая помогает быстро оценить потенциальный риск изменений и приоритизировать тестирование.

# %% [markdown]
# # Финальное summary анализа
#
# В ходе работы нейро-сотрудника **AI Release Guardian** были выполнены следующие этапы:
#
# 1. Подключение базы знаний
# 2. Построение RAG-индекса
# 3. Трассировка retrieval
# 4. DOM-анализ страницы
# 5. Декомпозиция интерфейса на testable objects
# 6. Генерация тестовых проверок
# 7. Анализ рисков страницы
# 8. Run-архитектура для хранения результатов
# 9. Diff-анализ между запусками
# 10. AI-интерпретация изменений интерфейса
#
# Все результаты анализа сохраняются в структуре **run-папок**, что позволяет отслеживать изменения интерфейса между версиями сайта.
#
# ---
#
# ## Роль нейро-сотрудника
#
# Таким образом система выполняет роль **AI Release Guardian**, помогая QA-инженеру:
#
# - выявлять потенциальные зоны риска
# - обнаруживать изменения интерфейса
# - анализировать возможные регрессии
# - приоритизировать тестирование после изменений
#
# Система сочетает:
#
# - извлечение фактов из интерфейса (DOM-анализ)
# - использование базы знаний QA-практик (RAG)
# - reasoning языковой модели
#
# Это позволяет автоматизировать часть аналитической работы тестировщика и ускорить анализ изменений интерфейса между релизами.

# %%
# ==========================================================
# Финальная сводка текущего run
# ==========================================================

import os
import json

summary = {
    "target_url": TARGET_URL,
    "site_name": site_name,
    "run_name": current_run_name,
    "total_testable_objects": len(testable_objects),
    "artifacts_dir": artifacts_dir
}

print("Финальная сводка run:\n")
print(json.dumps(summary, ensure_ascii=False, indent=2))
# Out:
# Финальная сводка run:
#
# {
#   "target_url": "https://trainer.sedtest-tools.ru/checkpass/",
#   "site_name": "trainer_sedtest-tools_ru",
#   "run_name": "run_009",
#   "total_testable_objects": 6,
#   "artifacts_dir": "/content/drive/MyDrive/AI_Release_Guardian_MVP/Sites/trainer_sedtest-tools_ru/runs/run_009"
# }

# %%
# ==========================================================
# Список файлов текущего run
# ==========================================================

print("Артефакты текущего run:\n")

for file_name in sorted(os.listdir(artifacts_dir)):
    print("-", file_name)
# Out:
# Артефакты текущего run:
#
# - generated_test_cases.json
# - generated_test_cases_by_type.json
# - page_screenshot.png
# - release_risk_analysis.json
# - representative_objects_by_type.json
# - run_summary.json
# - site_level_ui_checks.json
# - site_risk_analysis_comparison.json
# - site_risk_analysis_llm.json
# - site_risk_analysis_vsegpt.json
# - testable_objects.json
# - ui_diff_ai_analysis_comparison.json
# - ui_diff_ai_analysis_llm.json
# - ui_diff_ai_analysis_vsegpt.json
# - ui_diff_report.json
# - visual_consistency_checks.json

# %%
# ==========================================================
# Сохранение summary run
# ==========================================================

run_summary = {
    "target_url": TARGET_URL,
    "site_name": site_name,
    "run_name": current_run_name,
    "total_testable_objects": len(testable_objects),
    "artifacts": sorted(os.listdir(artifacts_dir))
}

run_summary_path = os.path.join(
    artifacts_dir,
    "run_summary.json"
)

with open(run_summary_path, "w", encoding="utf-8") as f:
    json.dump(run_summary, f, ensure_ascii=False, indent=2)

print("run_summary сохранён:")
print(run_summary_path)
# Out:
# run_summary сохранён:
# /content/drive/MyDrive/AI_Release_Guardian_MVP/Sites/trainer_sedtest-tools_ru/runs/run_009/run_summary.json

# %% [markdown]
# # Итог
#
# В рамках данной практической работы был реализован прототип нейро-сотрудника **AI Release Guardian**, выполняющего анализ интерфейса веб-страниц.
#
# Система предназначена для поддержки QA-процесса и помогает выявлять потенциальные риски интерфейса при изменениях веб-приложений.
#
# ---
#
# ## Основные возможности системы
#
# Реализованный прототип позволяет:
#
# - анализировать DOM-структуру страницы
# - декомпозировать интерфейс на **testable objects**
# - генерировать тестовые сценарии
# - выявлять потенциальные риски интерфейса
# - сохранять историю запусков анализа
# - сравнивать изменения интерфейса между версиями
# - выполнять AI-интерпретацию изменений интерфейса
#
# ---
#
# ## Использование LLM в системе
#
# В проекте применён гибридный подход к использованию языковых моделей:
#
# - **локальная русскоязычная модель** — используется для демонстрации применения русскоязычной LLM в архитектуре нейро-сотрудника
# - **внешний LLM API (VSEGPT)** — используется для более сложных аналитических задач и стабильного reasoning
#
# Такой подход позволяет сочетать экспериментальные возможности локальных моделей с более устойчивым AI-анализом.
#
# ---
#
# Таким образом реализованный прототип демонстрирует возможность использования LLM-технологий для автоматизации анализа интерфейсов и поддержки тестирования при выпуске новых версий веб-приложений.

# %% [markdown]
# # Генерация README проекта
#
# Для удобства публикации проекта на GitHub система автоматически генерирует файл **README.md** с описанием архитектуры и возможностей AI Release Guardian.
#
# README содержит:
#
# - описание архитектуры системы
# - основные этапы анализа интерфейса
# - используемые технологии
# - ключевые возможности нейро-сотрудника
#
# Автоматическая генерация README позволяет упростить документирование проекта и подготовить его к публикации в репозитории GitHub.

# %%
# ==========================================================
# Генерация README.md
# ==========================================================

readme_text = f"""
# AI Release Guardian

AI Release Guardian — прототип нейро-сотрудника для анализа веб-интерфейсов
и выявления рисков изменений между релизами.

Система анализирует DOM-структуру веб-страницы, декомпозирует интерфейс
на тестируемые объекты и использует LLM для генерации тестов и анализа рисков.

---

## Возможности системы

AI Release Guardian помогает QA-инженеру автоматически:

- анализировать структуру интерфейса веб-страницы
- выделять testable objects
- группировать элементы по типам
- генерировать тестовые сценарии
- анализировать UX и функциональные риски
- выполнять UI diff между версиями страницы
- оценивать release risk
- сохранять историю запусков анализа

---

## Архитектура системы

DOM analysis (Selenium + BeautifulSoup)

↓

Testable objects extraction

↓

Representative elements selection

↓

RAG retrieval (knowledge base)

↓

LLM reasoning

↓

Test generation (rule-based + LLM)

↓

Page summary generation

↓

Site-level UI checks

↓

Visual consistency checks

↓

Page risk analysis

↓

Run artifacts storage

↓

UI diff analysis

↓

AI diff interpretation

↓

Release risk score

---

## Используемые технологии

- Python
- Selenium
- BeautifulSoup
- LlamaIndex
- Sentence Transformers
- HuggingFace embeddings
- Русскоязычная LLM (локальная)
- VSEGPT API

---

## RAG и снижение галлюцинаций

В проекте используются техники повышения качества RAG:

- Query enrichment (расширение запросов)
- DOM-grounded retrieval
- Фильтрация контекста
- Representative elements
- Структурированные testable objects
- Run-based анализ интерфейса
- Разделение rule-based и AI-генерации

---

## Структура run

Sites/
  site_name/
    runs/
      run_001/
      run_002/

---

## Последний запуск

Site: {site_name}

Run: {current_run_name}

Total testable objects: {len(testable_objects)}

Artifacts directory:
{run_dir}

"""

readme_path = os.path.join(artifacts_dir, "README.md")

with open(readme_path, "w", encoding="utf-8") as f:
    f.write(readme_text)

print("README.md создан:")
print(readme_path)
# Out:
# README.md создан:
# /content/drive/MyDrive/AI_Release_Guardian_MVP/Sites/trainer_sedtest-tools_ru/runs/run_009/README.md
